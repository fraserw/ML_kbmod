# %% [markdown]
# # MOPS for KBmod
#
# Based off the CNN developed for the first ML search of the New Horizons 2020 search

# %%
import os, glob, sys
import time

import random
"""Import the basics: numpy, pandas, matplotlib, etc."""
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyl
import matplotlib.gridspec as gridspec
import pickle
"""Import keras and other ML tools"""
import tensorflow as tf
import keras

from keras.models import Model, load_model, Sequential
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv3D, Conv2D, MaxPool3D, MaxPool2D
from keras.layers.core import Dropout, Lambda
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
"""Import scikit learn tools"""
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.utils.multiclass import unique_labels
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
"""Import astropy libraries"""
from astropy.io import fits
from astropy import wcs
from astropy.nddata import Cutout2D
from astropy.visualization import interval

from trippy import tzscale
from trippy.trippy_utils import expand2d, downSample2d

from convenience_utils import calc_ecliptic_angle

from utils import shuffle

# %%
image_data_type = 'float32'

batch_size = 16 # production used 128
dropout_rate = 0.2
test_fraction = 0.05
select_bad_at_random = True
badGoodRatio = 0.8*3.0#1.5
bad_edge_enhancement = 0.002
useMedForNans = False #otherwise zero is used
useZscale = False


shuffle_augment = False # shuffle bootstrapping augmentation
double_flip = False # mirror vertically and horizontally augmentation
add_noise = False
noise_level=3.0


#good ranges [19,21.5], [21, 23.5] [23.5,25.5], [25.5, 26.8]
nukeBright = 25.0 # if set to a real value, all fainter planted source associations will be set to false
nukeFaint = 26.8 # if set to a real value, all fainter planted source associations will be set to false
dist_lim = 3.5 #association to planted source
save_model_iteration = False

useSampleWeights = True

useTripletGrids = True



"""These are some of the flags."""
visits = ['03072', '03093']

chips = []
#for i in range(103,-1,-1):
for i in range(104):
    if i==9: continue
    if i in [30,31, 89]: continue
    chips.append(str(i).zfill(3))
#chips = ['031','050']

# %% [markdown]
# # Data Exploration
#
# First read in the data, and make it look like the data from the tutorial

# %%
# load the data
#sns_frames = []
n_edge_added = 0
n_bad_total = 0

reference_fits_images = []
ecl_angles = []
stamp_files = []
kb_xys,fs = [],[]
for i, c in enumerate(chips):
    for j, v in enumerate(visits[:1]):
        warps_path = f'/media/fraserw/SecondStage/Projects/kbmod/DATA/rerun/diff_warpCompare/deepDiff/{v}/HSC-R2/warps'
        reference_fits_images.append(glob.glob(f'{warps_path}/{c}/DIFFEXP*fits')[0])
        ecl_ang = calc_ecliptic_angle(reference_fits_images[-1])
        ecl_angles.append(ecl_ang)
        if c=='050':
            ref_ecl_ang = ecl_ang
            print(ref_ecl_ang)
ecl_angles = np.array(ecl_angles)
rots = (ref_ecl_ang-ecl_angles)*180./np.pi
print(len(rots))
corners = np.array([-270., -180., -90., 0., 90., 180., 270.])
for i,r in enumerate(rots):
    rot = corners[np.argmin(np.abs(r-corners))]
    if rot<0: 
        rot+=360.
    print(chips[i%len(chips)],r,rot)
    rots[i] = rot/90.
rots = rots.astype(np.int)
# Out:
# 1.4412754795592164
# 100
# 000 -1.18808801867614 0.0
# 001 -0.09453831954545558 0.0
# 002 0.8744980819135028 0.0
# 003 1.8220850830578461 0.0
# 004 -2.1419920431726283 0.0
# 005 -1.0281424405745374 0.0
# 006 -0.16998761512827165 0.0
# 007 0.6729133575735556 0.0
# 008 1.3647796264404044 0.0
# 010 -1.7521249006635788 0.0
# 011 -0.8132820671602755 0.0
# 012 -0.18030994509453574 0.0
# 013 0.4196113635608986 0.0
# 014 1.0565958106580668 0.0
# 015 1.6194045314479253 0.0
# 016 178.5708055381495 180.0
# 017 179.28830235636485 180.0
# 018 179.833517837324 180.0
# 019 0.3175541021766452 0.0
# 020 0.7313349596999847 0.0
# 021 1.2064609133897453 0.0
# 022 178.10522623289881 180.0
# 023 178.93396660255365 180.0
# 024 179.45976272045675 180.0
# 025 179.86591912393425 180.0
# 026 0.1805464075787674 0.0
# 027 0.49840039885517345 0.0
# 028 0.7765309092959752 0.0
# 029 1.0202150843358275 0.0
# 032 179.59403802004894 180.0
# 033 179.90643617324594 180.0
# 034 0.0799578687083001 0.0
# 035 0.23008868736247362 0.0
# 036 0.3815383930413976 0.0
# 037 0.4622364771625722 0.0
# 038 179.07843527887323 180.0
# 039 179.45840713730152 180.0
# 040 179.73771484683465 180.0
# 041 179.91378868276703 180.0
# 042 0.02965853098149966 0.0
# 043 0.07388376456485665 0.0
# 044 0.06354975666858569 0.0
# 045 -0.031103845202225176 0.0
# 046 179.52922019699835 180.0
# 047 179.78122715868162 180.0
# 048 179.89453416996582 180.0
# 049 179.95738771074488 180.0
# 050 0.0 0.0
# 051 -0.06741875751258361 0.0
# 052 -0.28446567402936074 0.0
# 053 -0.5022548979685233 0.0
# 054 179.9973272800144 180.0
# 055 180.04738547632883 180.0
# 056 180.07321877165077 180.0
# 057 179.9791593297475 180.0
# 058 -0.10297487790594989 0.0
# 059 -0.288203867960715 0.0
# 060 -0.5651107180326668 0.0
# 061 -0.9647304896860784 0.0
# 062 180.52266971424956 180.0
# 063 180.3991850054077 180.0
# 064 180.25468974005295 180.0
# 065 180.09370830697458 180.0
# 066 -0.14714920294124786 0.0
# 067 -0.4538658185978695 0.0
# 068 -0.8549920173596116 0.0
# 069 -1.4864798734313367 0.0
# 070 180.98191635615106 180.0
# 071 180.75245674623008 180.0
# 072 180.48492294608812 180.0
# 073 180.19633675270632 180.0
# 074 -0.16769087716706144 0.0
# 075 -0.5983887968294286 0.0
# 076 -1.1699695148998783 0.0
# 077 -1.9408908861548368 0.0
# 078 181.19181043094463 180.0
# 079 180.74583336749686 180.0
# 080 180.2819340352665 180.0
# 081 -0.18112631200649937 0.0
# 082 -0.7319021330241241 0.0
# 083 -1.4533147057833897 0.0
# 084 181.666114507745 180.0
# 085 181.02601502587268 180.0
# 086 180.42011219422972 180.0
# 087 179.78062497290253 180.0
# 088 179.06437458069956 180.0
# 090 182.18588003444356 180.0
# 091 181.39387825512728 180.0
# 092 180.61074486085488 180.0
# 093 179.789938454981 180.0
# 094 178.91964541505914 180.0
# 095 177.77219128639027 180.0
# 096 181.79616525751084 180.0
# 097 180.8325935312042 180.0
# 098 179.80919583053856 180.0
# 099 178.6996099031898 180.0
# 100 87.62485028341548 90.0
# 101 91.7918628499445 90.0
# 102 -88.15120963711033 270.0
# 103 -92.42493032748598 270.0

# %%
gridType = ''
if useTripletGrids:
    gridType = '_tg'
    
counter = 0
for i, c in enumerate(chips):
    for j, v in enumerate(visits):
        stamps_path = f'/media/fraserw/rocketdata/Projects/kbmod/stamps/{v}'
        warps_path = f'/media/fraserw/SecondStage/Projects/kbmod/DATA/rerun/diff_warpCompare/deepDiff/{v}/HSC-R2/warps'
        reference_fits_images.append(glob.glob(f'{warps_path}/{c}/DIFFEXP*fits')[0])

        stamp_files.append(f'{stamps_path}/stamps{gridType}_{c}.pickle')

        
        ### get the image header and setup a WCS
        with fits.open(reference_fits_images[-1]) as han:
            header = han[1].header
            (A,B) = han[1].data.shape
            
        im_wcs = wcs.WCS(header)

        
        ### load the kbmod results
        kb_xy = []
        if os.path.isfile(f'/media/fraserw/rocketdata/Projects/kbmod/warps_results/{v}/results_{c}_upper_0/results_MERGED.txt'):
            #check if the kbmod results from CANFAR are available
            with open(f'/media/fraserw/rocketdata/Projects/kbmod/warps_results/{v}/results_{c}_upper_0/results_MERGED.txt') as han:
                data = han.readlines()
        else:
            ### otherwise open a local copy
            with open(f'/media/fraserw/rocketdata/Projects/kbmod/warps_results/{v}/results_{c}_lower/results_LOWER.txt') as han:
                data = han.readlines()
            with open(f'/media/fraserw/rocketdata/Projects/kbmod/warps_results/{v}/results_{c}_upper/results_UPPER.txt') as han:
                data += han.readlines()

        for ii in range(len(data)):
            s = data[ii].split()
            x, y = float(s[5]), float(s[7])
            repeat = False
            for jj in range(len(kb_xy)):
                if kb_xy[jj][0]==x and kb_xy[jj][1]==y:
                    repeat = True
                    break
            if not repeat:
                kb_xy.append([float(s[5]) , float(s[7]) , float(s[9]), float(s[11]), float(s[1]), 0.0])
        kb_xy = np.array(kb_xy)
        
        ### load the plantlist sources
        p_xy = []
        if v == '03072':
            with open(f'/media/fraserw/rocketdata/Projects/ML_SNS_MOPS/HSC_May25-lsst/rerun/processCcdOutputs/{v}/HSC-R2/corr/planted/CORR-0218606-{c}.plantList') as han:
                data = han.readlines()
        elif v == '03093':
            with open(f'/media/fraserw/rocketdata/Projects/ML_SNS_MOPS/HSC_June19-lsst/rerun/processCcdOutputs/{v}/HSC-R2/corr/planted/CORR-0220262-{c}.plantList') as han:
                data = han.readlines()
                
        for ii in range(1,len(data)):
            s = data[ii].split()
            ra,dec = float(s[1]), float(s[2])
            coord = np.array(im_wcs.all_world2pix(ra, dec, 0))

            x,y = coord[0],coord[1]
            #x = float(s[3]) + offsets[c][0]
            #y = float(s[4]) + offsets[c][1]
            repeat = False
            for jj in range(len(p_xy)):
                if p_xy[jj][0] == x and p_xy[jj][1]==y:
                    p_xy[jj][2]-=0.75
                    repeat = True

            if not repeat:
                p_xy.append([x, y, float(s[9]), 0])
                
        if len(p_xy)>0:
            p_xy = np.array(p_xy)
            p_xy = p_xy[np.argsort(p_xy[:,2])]
            p_xy = p_xy[np.where((p_xy[:,2]>nukeBright)&(p_xy[:,2]<nukeFaint))]

            #label the good and bad sources
            for ii in range(len(p_xy)):
                d = ((p_xy[ii, 0] - kb_xy[:, 0])**2 + (p_xy[ii, 1] - kb_xy[:, 1])**2 )**0.5
                args = np.argsort(d)

                if d[args[0]]<dist_lim:
                    kb_xy[args[0],-1] = p_xy[ii,2]
                    #print(kb_xy[args[0]])
            #print(p_xy[np.where(p_xy[:,2]>=nukeFaint)])
                    
        w_bad = np.where(kb_xy[:,-1]==0)
        w_good = np.where(kb_xy[:,-1]>0)
        print(v, c, len(w_bad[0]), len(w_good[0]), len(kb_xy))

        #load the stamps
        with open(stamp_files[-1], 'rb') as han:
            f = pickle.load(han)
        
        ### trim to just the best cutout
        f = f[:,5,:,:]

            
        n_good = len(w_good[0])
        
        n_bad_keep = max(1, int(n_good*badGoodRatio))
        if n_bad_keep>0:
            if not select_bad_at_random:
                # sequential selection
                step = int(len(w[0])/n_bad_keep)
                w = w_bad[0][np.arange(0,len(w_bad[0]),step)]
            else:
                # random selection
                w = w_bad[0][(np.random.rand(n_bad_keep)*len(w_bad[0])).astype(np.int)]

        ### add edge bad sources
        if bad_edge_enhancement>0:
            NN = 0
            w_edge = np.where((kb_xy[:, -1] ==0) & ((kb_xy[:,0]<25) | ((B-kb_xy[:,0])<20) | (kb_xy[:, 1]<25) | ((A-kb_xy[:,1])<20)))
            n_edge_bad_keep = int(len(w_edge[0])*bad_edge_enhancement)
            while NN<n_edge_bad_keep:
                j = int(np.random.rand(1)*len(w_edge[0]))
                if j not in w:
                    w = np.append(w, j)
                    NN += 1
        n_edge_added+=NN
        n_bad_total += len(w)
        
        w = np.concatenate([w, w_good[0]])
        
        
        print('Number good, bad, and number edge enhanced:', n_good, n_bad_keep, n_edge_bad_keep)

        f = f[w]
        kb_xy = kb_xy[w]

        ### rotate frames
        # k should be -rots!
        if rots[counter%len(chips)]!=0:
            f = np.rot90(f, k=-rots[counter%len(chips)], axes=(1, 2))
        counter+=1
        
        
        fs.append(f)
        kb_xys.append(kb_xy)
        del f, kb_xy

        


source_details = np.concatenate(kb_xys)
sns_frames = np.concatenate(fs)
print(sns_frames.shape)
del kb_xys
del fs
    
print('Number of bad edge sources added:',n_edge_added)
print(f'Number of total bad sources in sample {n_bad_total}')
# Out:
# 03072 000 2493 11 2504
# Number good, bad, and number edge enhanced: 11 26 0
# 03093 000 2609 8 2617
# Number good, bad, and number edge enhanced: 8 19 0
# 03072 001 3634 11 3645
# Number good, bad, and number edge enhanced: 11 26 0
# 03093 001 4353 11 4364
# Number good, bad, and number edge enhanced: 11 26 0
# 03072 002 3464 8 3472
# Number good, bad, and number edge enhanced: 8 19 0
# 03093 002 4255 13 4268
# Number good, bad, and number edge enhanced: 13 31 0
# 03072 003 4055 13 4068
# Number good, bad, and number edge enhanced: 13 31 0
# 03093 003 4022 17 4039
# Number good, bad, and number edge enhanced: 17 40 0
# 03072 004 2153 5 2158
# Number good, bad, and number edge enhanced: 5 12 0
# 03093 004 2992 9 3001
# Number good, bad, and number edge enhanced: 9 21 0
# 03072 005 3328 5 3333
# Number good, bad, and number edge enhanced: 5 12 0
# 03093 005 3660 14 3674
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 006 3469 13 3482
# Number good, bad, and number edge enhanced: 13 31 0
# 03093 006 3900 16 3916
# Number good, bad, and number edge enhanced: 16 38 0
# 03072 007 3755 13 3768
# Number good, bad, and number edge enhanced: 13 31 0
# 03093 007 3897 15 3912
# Number good, bad, and number edge enhanced: 15 36 0
# 03072 008 3769 21 3790
# Number good, bad, and number edge enhanced: 21 50 0
# 03093 008 3874 10 3884
# Number good, bad, and number edge enhanced: 10 24 0
# 03072 010 3198 19 3217
# Number good, bad, and number edge enhanced: 19 45 0
# 03093 010 4198 10 4208
# Number good, bad, and number edge enhanced: 10 24 0
# 03072 011 3430 14 3444
# Number good, bad, and number edge enhanced: 14 33 0
# 03093 011 4196 12 4208
# Number good, bad, and number edge enhanced: 12 28 0
# 03072 012 3061 11 3072
# Number good, bad, and number edge enhanced: 11 26 0
# 03093 012 3832 15 3847
# Number good, bad, and number edge enhanced: 15 36 0
# 03072 013 4270 13 4283
# Number good, bad, and number edge enhanced: 13 31 0
# 03093 013 3499 12 3511
# Number good, bad, and number edge enhanced: 12 28 0
# 03072 014 3968 17 3985
# Number good, bad, and number edge enhanced: 17 40 0
# 03093 014 3510 12 3522
# Number good, bad, and number edge enhanced: 12 28 0
# 03072 015 4013 18 4031
# Number good, bad, and number edge enhanced: 18 43 0
# 03093 015 4196 26 4222
# Number good, bad, and number edge enhanced: 26 62 0
# 03072 016 3674 15 3689
# Number good, bad, and number edge enhanced: 15 36 0
# 03093 016 3958 15 3973
# Number good, bad, and number edge enhanced: 15 36 0
# 03072 017 4003 11 4014
# Number good, bad, and number edge enhanced: 11 26 0
# 03093 017 3881 17 3898
# Number good, bad, and number edge enhanced: 17 40 0
# 03072 018 4063 15 4078
# Number good, bad, and number edge enhanced: 15 36 0
# 03093 018 3592 13 3605
# Number good, bad, and number edge enhanced: 13 31 0
# 03072 019 3558 16 3574
# Number good, bad, and number edge enhanced: 16 38 0
# 03093 019 3443 14 3457
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 020 4486 16 4502
# Number good, bad, and number edge enhanced: 16 38 0
# 03093 020 3979 13 3992
# Number good, bad, and number edge enhanced: 13 31 0
# 03072 021 3824 18 3842
# Number good, bad, and number edge enhanced: 18 43 0
# 03093 021 4222 19 4241
# Number good, bad, and number edge enhanced: 19 45 0
# 03072 022 2571 3 2574
# Number good, bad, and number edge enhanced: 3 7 0
# 03093 022 2930 6 2936
# Number good, bad, and number edge enhanced: 6 14 0
# 03072 023 2946 3 2949
# Number good, bad, and number edge enhanced: 3 7 0
# 03093 023 3662 13 3675
# Number good, bad, and number edge enhanced: 13 31 0
# 03072 024 3222 8 3230
# Number good, bad, and number edge enhanced: 8 19 0
# 03093 024 4277 13 4290
# Number good, bad, and number edge enhanced: 13 31 0
# 03072 025 3842 19 3861
# Number good, bad, and number edge enhanced: 19 45 0
# 03093 025 3334 16 3350
# Number good, bad, and number edge enhanced: 16 38 0
# 03072 026 3985 19 4004
# Number good, bad, and number edge enhanced: 19 45 0
# 03093 026 3440 14 3454
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 027 1222 14 1236
# Number good, bad, and number edge enhanced: 14 33 0
# 03093 027 3619 19 3638
# Number good, bad, and number edge enhanced: 19 45 0
# 03072 028 4005 21 4026
# Number good, bad, and number edge enhanced: 21 50 0
# 03093 028 3830 34 3864
# Number good, bad, and number edge enhanced: 34 81 0
# 03072 029 3140 12 3152
# Number good, bad, and number edge enhanced: 12 28 0
# 03093 029 2781 7 2788
# Number good, bad, and number edge enhanced: 7 16 0
# 03072 032 1941 4 1945
# Number good, bad, and number edge enhanced: 4 9 0
# 03093 032 3919 11 3930
# Number good, bad, and number edge enhanced: 11 26 0
# 03072 033 877 6 883
# Number good, bad, and number edge enhanced: 6 14 0
# 03093 033 1727 12 1739
# Number good, bad, and number edge enhanced: 12 28 0
# 03072 034 2032 10 2042
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 034 3291 8 3299
# Number good, bad, and number edge enhanced: 8 19 0
# 03072 035 1939 17 1956
# Number good, bad, and number edge enhanced: 17 40 0
# 03093 035 3657 20 3677
# Number good, bad, and number edge enhanced: 20 48 0
# 03072 036 2178 17 2195
# Number good, bad, and number edge enhanced: 17 40 0
# 03093 036 3970 22 3992
# Number good, bad, and number edge enhanced: 22 52 0
# 03072 037 1476 10 1486
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 037 3944 15 3959
# Number good, bad, and number edge enhanced: 15 36 0
# 03072 038 1961 8 1969
# Number good, bad, and number edge enhanced: 8 19 0
# 03093 038 3961 12 3973
# Number good, bad, and number edge enhanced: 12 28 0
# 03072 039 2218 11 2229
# Number good, bad, and number edge enhanced: 11 26 0
# 03093 039 3490 14 3504
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 040 1810 7 1817
# Number good, bad, and number edge enhanced: 7 16 0
# 03093 040 3835 8 3843
# Number good, bad, and number edge enhanced: 8 19 0
# 03072 041 2271 9 2280
# Number good, bad, and number edge enhanced: 9 21 0
# 03093 041 3165 12 3177
# Number good, bad, and number edge enhanced: 12 28 0
# 03072 042 2043 7 2050
# Number good, bad, and number edge enhanced: 7 16 0
# 03093 042 3718 17 3735
# Number good, bad, and number edge enhanced: 17 40 0
# 03072 043 992 14 1006
# Number good, bad, and number edge enhanced: 14 33 0
# 03093 043 2829 14 2843
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 044 1456 15 1471
# Number good, bad, and number edge enhanced: 15 36 0
# 03093 044 4122 27 4149
# Number good, bad, and number edge enhanced: 27 64 0
# 03072 045 2037 19 2056
# Number good, bad, and number edge enhanced: 19 45 0
# 03093 045 4308 17 4325
# Number good, bad, and number edge enhanced: 17 40 0
# 03072 046 1931 10 1941
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 046 4141 18 4159
# Number good, bad, and number edge enhanced: 18 43 0
# 03072 047 1831 12 1843
# Number good, bad, and number edge enhanced: 12 28 0
# 03093 047 3734 16 3750
# Number good, bad, and number edge enhanced: 16 38 0
# 03072 048 2470 13 2483
# Number good, bad, and number edge enhanced: 13 31 0
# 03093 048 3606 18 3624
# Number good, bad, and number edge enhanced: 18 43 0
# 03072 049 2044 5 2049
# Number good, bad, and number edge enhanced: 5 12 0
# 03093 049 3379 20 3399
# Number good, bad, and number edge enhanced: 20 48 0
# 03072 050 1792 14 1806
# Number good, bad, and number edge enhanced: 14 33 0
# 03093 050 3623 24 3647
# Number good, bad, and number edge enhanced: 24 57 0
# 03072 051 1643 14 1657
# Number good, bad, and number edge enhanced: 14 33 0
# 03093 051 3931 14 3945
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 052 1986 17 2003
# Number good, bad, and number edge enhanced: 17 40 0
# 03093 052 3909 26 3935
# Number good, bad, and number edge enhanced: 26 62 0
# 03072 053 1514 11 1525
# Number good, bad, and number edge enhanced: 11 26 0
# 03093 053 4262 20 4282
# Number good, bad, and number edge enhanced: 20 48 0
# 03072 054 2047 10 2057
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 054 3848 7 3855
# Number good, bad, and number edge enhanced: 7 16 0
# 03072 055 2223 12 2235
# Number good, bad, and number edge enhanced: 12 28 0
# 03093 055 3846 10 3856
# Number good, bad, and number edge enhanced: 10 24 0
# 03072 056 1883 10 1893
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 056 3880 15 3895
# Number good, bad, and number edge enhanced: 15 36 0
# 03072 057 2179 7 2186
# Number good, bad, and number edge enhanced: 7 16 0
# 03093 057 3517 8 3525
# Number good, bad, and number edge enhanced: 8 19 0
# 03072 058 1964 11 1975
# Number good, bad, and number edge enhanced: 11 26 0
# 03093 058 3794 10 3804
# Number good, bad, and number edge enhanced: 10 24 0
# 03072 059 1850 14 1864
# Number good, bad, and number edge enhanced: 14 33 0
# 03093 059 3041 2 3043
# Number good, bad, and number edge enhanced: 2 4 0
# 03072 060 2053 15 2068
# Number good, bad, and number edge enhanced: 15 36 0
# 03093 060 4290 21 4311
# Number good, bad, and number edge enhanced: 21 50 0
# 03072 061 1353 9 1362
# Number good, bad, and number edge enhanced: 9 21 0
# 03093 061 4620 15 4635
# Number good, bad, and number edge enhanced: 15 36 0
# 03072 062 1742 3 1745
# Number good, bad, and number edge enhanced: 3 7 0
# 03093 062 3847 4 3851
# Number good, bad, and number edge enhanced: 4 9 0
# 03072 063 2363 7 2370
# Number good, bad, and number edge enhanced: 7 16 0
# 03093 063 3837 15 3852
# Number good, bad, and number edge enhanced: 15 36 0
# 03072 064 2076 10 2086
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 064 3890 18 3908
# Number good, bad, and number edge enhanced: 18 43 0
# 03072 065 2193 12 2205
# Number good, bad, and number edge enhanced: 12 28 0
# 03093 065 3590 20 3610
# Number good, bad, and number edge enhanced: 20 48 0
# 03072 066 2101 10 2111
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 066 4275 10 4285
# Number good, bad, and number edge enhanced: 10 24 0
# 03072 067 1507 18 1525
# Number good, bad, and number edge enhanced: 18 43 0
# 03093 067 4013 14 4027
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 068 1565 17 1582
# Number good, bad, and number edge enhanced: 17 40 0
# 03093 068 4433 30 4463
# Number good, bad, and number edge enhanced: 30 72 0
# 03072 069 1563 8 1571
# Number good, bad, and number edge enhanced: 8 19 0
# 03093 069 4109 23 4132
# Number good, bad, and number edge enhanced: 23 55 0
# 03072 070 1380 8 1388
# Number good, bad, and number edge enhanced: 8 19 0
# 03093 070 3274 0 3274
# Number good, bad, and number edge enhanced: 0 1 0
# 03072 071 2419 10 2429
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 071 3968 6 3974
# Number good, bad, and number edge enhanced: 6 14 0
# 03072 072 2357 13 2370
# Number good, bad, and number edge enhanced: 13 31 0
# 03093 072 3809 18 3827
# Number good, bad, and number edge enhanced: 18 43 0
# 03072 073 1926 4 1930
# Number good, bad, and number edge enhanced: 4 9 0
# 03093 073 3862 17 3879
# Number good, bad, and number edge enhanced: 17 40 0
# 03072 074 4416 14 4430
# Number good, bad, and number edge enhanced: 14 33 0
# 03093 074 3641 14 3655
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 075 2300 17 2317
# Number good, bad, and number edge enhanced: 17 40 0
# 03093 075 4095 18 4113
# Number good, bad, and number edge enhanced: 18 43 0
# 03072 076 2114 21 2135
# Number good, bad, and number edge enhanced: 21 50 0
# 03093 076 4461 20 4481
# Number good, bad, and number edge enhanced: 20 48 0
# 03072 077 1309 8 1317
# Number good, bad, and number edge enhanced: 8 19 0
# 03093 077 3629 14 3643
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 078 2029 7 2036
# Number good, bad, and number edge enhanced: 7 16 0
# 03093 078 4119 2 4121
# Number good, bad, and number edge enhanced: 2 4 0
# 03072 079 2607 17 2624
# Number good, bad, and number edge enhanced: 17 40 0
# 03093 079 4180 12 4192
# Number good, bad, and number edge enhanced: 12 28 0
# 03072 080 1672 11 1683
# Number good, bad, and number edge enhanced: 11 26 0
# 03093 080 3965 12 3977
# Number good, bad, and number edge enhanced: 12 28 0
# 03072 081 2364 15 2379
# Number good, bad, and number edge enhanced: 15 36 0
# 03093 081 4030 8 4038
# Number good, bad, and number edge enhanced: 8 19 0
# 03072 082 2093 14 2107
# Number good, bad, and number edge enhanced: 14 33 0
# 03093 082 3897 15 3912
# Number good, bad, and number edge enhanced: 15 36 0
# 03072 083 2107 10 2117
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 083 4576 18 4594
# Number good, bad, and number edge enhanced: 18 43 0
# 03072 084 2211 8 2219
# Number good, bad, and number edge enhanced: 8 19 0
# 03093 084 4072 0 4072
# Number good, bad, and number edge enhanced: 0 1 0
# 03072 085 2800 10 2810
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 085 4249 10 4259
# Number good, bad, and number edge enhanced: 10 24 0
# 03072 086 1848 5 1853
# Number good, bad, and number edge enhanced: 5 12 0
# 03093 086 4081 14 4095
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 087 1320 10 1330
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 087 3974 18 3992
# Number good, bad, and number edge enhanced: 18 43 0
# 03072 088 2407 9 2416
# Number good, bad, and number edge enhanced: 9 21 0
# 03093 088 3761 12 3773
# Number good, bad, and number edge enhanced: 12 28 0
# 03072 090 1640 4 1644
# Number good, bad, and number edge enhanced: 4 9 0
# 03093 090 2920 0 2920
# Number good, bad, and number edge enhanced: 0 1 0
# 03072 091 2157 12 2169
# Number good, bad, and number edge enhanced: 12 28 0
# 03093 091 4375 0 4375
# Number good, bad, and number edge enhanced: 0 1 0
# 03072 092 1680 3 1683
# Number good, bad, and number edge enhanced: 3 7 0
# 03093 092 4204 2 4206
# Number good, bad, and number edge enhanced: 2 4 0
# 03072 093 1682 12 1694
# Number good, bad, and number edge enhanced: 12 28 0
# 03093 093 3758 14 3772
# Number good, bad, and number edge enhanced: 14 33 0
# 03072 094 1687 7 1694
# Number good, bad, and number edge enhanced: 7 16 0
# 03093 094 3196 11 3207
# Number good, bad, and number edge enhanced: 11 26 0
# 03072 095 1385 10 1395
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 095 3266 6 3272
# Number good, bad, and number edge enhanced: 6 14 0
# 03072 096 1796 10 1806
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 096 4058 0 4058
# Number good, bad, and number edge enhanced: 0 1 0
# 03072 097 2011 10 2021
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 097 4204 0 4204
# Number good, bad, and number edge enhanced: 0 1 0
# 03072 098 2028 10 2038
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 098 4197 13 4210
# Number good, bad, and number edge enhanced: 13 31 0
# 03072 099 1962 15 1977
# Number good, bad, and number edge enhanced: 15 36 0
# 03093 099 4106 7 4113
# Number good, bad, and number edge enhanced: 7 16 0
# 03072 100 1261 7 1268
# Number good, bad, and number edge enhanced: 7 16 0
# 03093 100 2186 4 2190
# Number good, bad, and number edge enhanced: 4 9 0
# 03072 101 1127 7 1134
# Number good, bad, and number edge enhanced: 7 16 0
# 03093 101 2359 8 2367
# Number good, bad, and number edge enhanced: 8 19 0
# 03072 102 1247 8 1255
# Number good, bad, and number edge enhanced: 8 19 0
# 03093 102 2472 0 2472
# Number good, bad, and number edge enhanced: 0 1 0
# 03072 103 1073 10 1083
# Number good, bad, and number edge enhanced: 10 24 0
# 03093 103 2530 7 2537
# Number good, bad, and number edge enhanced: 7 16 0
# (8231, 21, 21)
# Number of bad edge sources added: 0
# Number of total bad sources in sample 5790

# %%
print(np.min(sns_frames), np.max(sns_frames))
# Out:
# -2134.1377 5359.1846

# %%
# categorize the sources.
# column 0 is bad source. Labelled when ==1
# column 1 is good source
sns_labels = np.zeros((source_details[:, 5].shape[0], 2), dtype=image_data_type)
w = np.where(source_details[:, -1]==0)
W = np.where((source_details[:, -1]>0))
print('Number of planted sources in the dataset:', len(W[0]))
sns_labels[w, 0] = 1.0
sns_labels[W, 1] = 1.0


if useMedForNans:
    med = np.nanmedian(sns_frames)
else:
    med = 0.0
    
w_nan = np.where(np.isnan(sns_frames))
sns_frames[w_nan] = med

(z1, z2) = tzscale.zscale(sns_frames)
normer = interval.ManualInterval(z1,z2)

mean = np.nanmean(sns_frames)
std = np.nanstd(sns_frames)
print(mean, std)

sns_frames -= mean
sns_frames /= std
print('Normalized frame min and max:', np.nanmin(sns_frames), np.nanmax(sns_frames))



# expand the image data to shape (:, :, :, 1) for the CNN
#sns_frames = np.expand_dims(sns_frames, axis=3)
sns_frames = np.expand_dims(sns_frames, axis=3)
print(sns_frames.shape)
# Out:
# Number of planted sources in the dataset: 2441
# 2.8386428 45.166306
# Normalized frame min and max: -47.313507 118.59163
# (8231, 21, 21, 1)

# %%
if shuffle_augment:
    a = np.copy(sns_frames)
    b = np.copy(sns_frames)
    c = np.copy(sns_frames)
    d = np.copy(sns_frames)
    a[:,:-1,:,:] = sns_frames[:,1:,:,:]
    b[:,1:,:,:] = sns_frames[:,:-1,:,:]
    c[:,:, :-1,:] = sns_frames[:,:,1:,:]
    d[:,:, 1:,:] = sns_frames[:,:,:-1,:]
    sns_frames = np.concatenate([sns_frames,a,b,c,d])
    sns_labels = np.concatenate([sns_labels, np.copy(sns_labels), np.copy(sns_labels), np.copy(sns_labels), np.copy(sns_labels)])
    source_details = np.concatenate([source_details, np.copy(source_details), np.copy(source_details), np.copy(source_details), np.copy(source_details)])


if double_flip:

    sns_frames = np.concatenate([sns_frames, sns_frames[:, ::-1, ::-1, :]])
    sns_labels = np.concatenate([sns_labels, sns_labels])
    source_details = np.concatenate([source_details, source_details])
    
    
if add_noise:
    noise = np.random.normal(0.0, noise_level, sns_frames.shape).astype(image_data_type)
    #noised_sns_frames = normed_sns_frames + np.random.normal(0.0, noise_level, normed_sns_frames.shape, dtype=image_data_type)
    sns_frames = np.concatenate([sns_frames, sns_frames+noise])
    sns_labels = np.concatenate([sns_labels, sns_labels])
    source_details = np.concatenate([source_details, source_details])
    #del noised_sns_frames
    del noise
    mean = np.mean(sns_frames)
    std = np.std(sns_frames)
    print(mean, std)

    sns_frames -= mean
    sns_frames /= std

# %%
print('Faintest source in dataset:', np.max(source_details[:, -1]))
# Out:
# Faintest source in dataset: 26.79

# %% [markdown]
# # Training and Test/Validation Samples
#
# In this part we will split our sample into two; one sample that we will use to train the neural network, aptly named the training sample, and another sample called the test sample. The network will not see the test sample itself during training, but we will use the trained neural network to predict its labels. It will therefore serve as validation to the accuracy of the neural network that has been trained using a different subset of images. We chose to set the size of the test sample as 15% of the total sample, as it is common practice to choose a test sample smaller in size compared to the training sample. It is important to make this split by roughly preserving the ratio of the labels within the total sample. Random splits may cause one of the labels to be underrepresented within training sample, thereby resulting in a neural network inacapable of accurate classifications as it is undertrained in one of the labels. We perform a stratified sampling below to preserve the original ratios of the two morphology types when making the split.
#
# I have modified the following to work with my data arrays, not those from the tutorial

# %%
"""
Use stratification to split the data into training & test samples.
This preserves the ratio of class 0 to class 1 objects when we split the
total sample into training and test samples. We choose the test sample to be 15%
of the total sample size.
"""

skf = StratifiedShuffleSplit(n_splits=1, test_size=test_fraction, random_state=41)
print(skf)
skf.split(sns_frames, sns_labels)


for train_index, test_index in skf.split(sns_frames, sns_labels):
    X_train, X_test = sns_frames[train_index], sns_frames[test_index]
    y_train, y_test = sns_labels[train_index], sns_labels[test_index]

#del sns_frames


print('Number of images in the training sample: ', X_train.shape[0])
print('Number of objects classified as real in the training sample: ',
      len(np.unique(np.where(y_train == [0, 1])[0])))
print('Number of objects classified as false in the training sample: ',
      len(np.unique(np.where(y_train == [1, 0])[0])))
print()
print('Number of images in the test sample: ', X_test.shape[0])
print('Number of objects classified as real in the validation sample: ',
      len(np.unique(np.where(y_test == [0, 1])[0])))
print('Number of objects classified as false in the validation sample: ',
      len(np.unique(np.where(y_test == [1, 0])[0])))
print()
print('Fraction of bad objects in the training sample',
      round((np.count_nonzero(y_train == [1, 0])/2)/X_train.shape[0], 3))

move_real_to_test = False
# remove the real source from the training set as a test to see what happens
if args[0] in train_index and move_real_to_test:
    w = np.where(train_index == args[0])

    print(X_train[w[0], 0, 0, 0])
    print(y_train[w[0]])
    
    X_test = np.concatenate([X_test, X_train[w[0]]])
    y_test = np.concatenate([y_test, y_train[w[0]]])
    test_index = np.append(test_index, [args[0]], -1)
    
    X_train = np.concatenate([X_train[:w[0][0]], X_train[w[0][0]+1:]])
    y_train = np.concatenate([y_train[:w[0][0]], y_train[w[0][0]+1:]])
    train_index = np.concatenate([train_index[:w[0][0]], train_index[w[0][0]+1:]])
    print(X_train.shape)
    print(y_train.shape)
    print(train_index.shape)
    print(X_test.shape)
    print(X_train[w[0][0],0, 0, 0])
    print(y_train[w[0]])
    print()
    print(X_test[-1, 0, 0, 0])
#w = np.where(train_index == args[0])
#y_train[w[0]][0] = 0.0
#y_train[w[0]][0] = 1.0
# Out:
# StratifiedShuffleSplit(n_splits=1, random_state=41, test_size=0.05,
#             train_size=None)
# Number of images in the training sample:  15638
# Number of objects classified as real in the training sample:  4638
# Number of objects classified as false in the training sample:  11000
#
# Number of images in the test sample:  824
# Number of objects classified as real in the validation sample:  244
# Number of objects classified as false in the validation sample:  580
#
# Fraction of bad objects in the training sample 0.703

# %%
if useSampleWeights:
    n_false_total = len(np.where(y_train[:,0]==1)[0]) + len(np.where(y_test[:,0]==1)[0])
    n_true_total = len(np.where(y_train[:,1]==1)[0]) + len(np.where(y_test[:,1]==1)[0])
    print('Fraction of good to bad sources:',n_true_total/n_false_total)
    
    true_weight = 1.0
    nominal_false_weight = 0.83
    false_weight = n_true_total*nominal_false_weight/n_false_total
    print('False weight:' , false_weight)
    
    train_weight = np.ones(y_train.shape[0], dtype = y_train.dtype)
    train_weight[np.where(y_train[:,0]==1)] = false_weight
    train_weight[np.where(y_train[:,1]==1)] = true_weight
    test_weight = np.ones(y_test.shape[0], dtype = y_train.dtype)
    test_weight[np.where(y_test[:,0]==1)] = false_weight
    test_weight[np.where(y_test[:,1]==1)] = true_weight
# Out:
# Fraction of good to bad sources: 0.4215889464594128
# False weight: 0.3499188255613126

# %% [markdown]
# # The Neural Network Model
#
# Below we define the neural network model we use for this task. This is a particularly and deliberately simple model. It consists only of convolution blocks (see introductory presentation), dropout layers, and dense layers as the final layers of the network to produce predictions. Dropout randomly ignores nodes within the network, in an effort to prevent overfitting. It becomes especially useful in small training samples, or inhomogeneous ones such as this case.
#
# The filters value is the number of separate kernels, each of size kernel_size that are created. In that sense, the .add(Conv2d()) line is adding a full network layer
#
# Flatten() reshapes the array to 1xn shape.
#
# Dense() sets up a normal hidden layer network.
#
# So in the example, we add two normal layers, the second one with output of two separate labels, as defined in unique_labs.

# %%
"""The 3D convolutional neural network model modified by Wes"""
# the one wes is tinkering with

def convnet_model(input_shape, training_labels, dropout_rate=dropout_rate):

    unique_labs = len(np.unique(training_labels))

    model = Sequential()

    # it seems having 2 hiddne layers of filter#=16 and max pooling between each does better than the version below
    #hidden layer 1 with Pooling
    """
    model.add(Conv3D(filters=16, kernel_size=(3, 3, 1), input_shape=input_shape, activation='relu', padding='same'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPool3D(pool_size=(2, 2, 2), padding='valid'))

    #hidden layer 2 with Pooling
    model.add(Conv3D(filters=16, kernel_size=(3, 3, 1), input_shape=input_shape, activation='relu', padding='same'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPool3D(pool_size=(2, 2, 2), padding='valid'))
    
    model.add(Flatten())
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dense(unique_labs, activation='softmax'))
    
    """

    ### for prodcution I used 16,16,8. 
    ### testing to see if I can fit bigger
    #hidden layer 1 
    model.add(Conv2D(filters=16, kernel_size=(3, 3), input_shape=input_shape, activation='relu', padding='same'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPool2D(pool_size=(2, 2), padding='valid'))
    
    #hidden layer 2 with Pooling
    model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=input_shape, activation='relu', padding='same'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPool2D(pool_size=(2, 2), padding='valid'))
    
    model.add(BatchNormalization())
    
    #hidden layer 3 with Pooling
    model.add(Conv2D(filters = 32, kernel_size=(3, 3), input_shape=input_shape, activation='relu', padding='same'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPool2D(pool_size=(2, 2), padding='valid'))


    model.add(Flatten())
    model.add(Dense(64, activation='sigmoid'))    
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dense(unique_labs, activation='softmax'))

    return model

# %% [markdown]
# # Fitting the Neural Network Model
#
# Here we train the neural network model defined above. The training session will output loss, and accuracy at each epoch. We also plot the progression of the loss and accuracy with respect to training epochs after the training is completed.

# %%
# callbacks
checkpointer = ModelCheckpoint('keras_convnet_model.h5', verbose=1)
early_stopper = EarlyStopping(monitor='loss', patience=2, verbose=1)



cn_model = convnet_model(X_train.shape[1:], y_train)
cn_model.summary()

cn_model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=["accuracy"])
epochs = 90

start = time.time()

#classifier = cn_model.fit(X_train, y_train, epochs=80, batch_size=batch_size, callbacks=[early_stopper, checkpointer])
if not useSampleWeights:
    classifier = cn_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[checkpointer])
else:
    classifier = cn_model.fit(X_train, y_train, sample_weight = train_weight,
                              epochs=epochs, 
                              batch_size=batch_size, callbacks=[checkpointer])

end = time.time()
print('Process completed in', round(end-start, 2), ' seconds')

"""
Plot accuracy/loss versus epoch
"""

fig = pyl.figure(figsize=(10,3))

ax1 = pyl.subplot(121)
ax1.plot(classifier.history['accuracy'], color='darkslategray', linewidth=2)
ax1.set_title('Model Accuracy')
ax1.set_ylabel('Accuracy')
ax1.set_xlabel('Epoch')

ax2 = pyl.subplot(122)
ax2.plot(classifier.history['loss'], color='crimson', linewidth=2)
ax2.set_title('Model Loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')

pyl.show()
pyl.close()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 21, 21, 16)        160
# _________________________________________________________________
# dropout (Dropout)            (None, 21, 21, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 32)        4640
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 5, 5, 32)          128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 32)          9248
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 32)          0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 26,722
# Trainable params: 26,658
# Non-trainable params: 64
# _________________________________________________________________
# Epoch 1/90
# 976/978 [============================>.] - ETA: 0s - loss: 0.1928 - accuracy: 0.8340
# Epoch 00001: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.1927 - accuracy: 0.8341
# Epoch 2/90
# 978/978 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9143
# Epoch 00002: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.1303 - accuracy: 0.9143
# Epoch 3/90
# 950/978 [============================>.] - ETA: 0s - loss: 0.1158 - accuracy: 0.9245
# Epoch 00003: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.1162 - accuracy: 0.9242
# Epoch 4/90
# 968/978 [============================>.] - ETA: 0s - loss: 0.1126 - accuracy: 0.9254
# Epoch 00004: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.1125 - accuracy: 0.9254
# Epoch 5/90
# 953/978 [============================>.] - ETA: 0s - loss: 0.1059 - accuracy: 0.9305
# Epoch 00005: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.1057 - accuracy: 0.9308
# Epoch 6/90
# 953/978 [============================>.] - ETA: 0s - loss: 0.1024 - accuracy: 0.9328
# Epoch 00006: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.1024 - accuracy: 0.9330
# Epoch 7/90
# 972/978 [============================>.] - ETA: 0s - loss: 0.1002 - accuracy: 0.9340
# Epoch 00007: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0999 - accuracy: 0.9343
# Epoch 8/90
# 971/978 [============================>.] - ETA: 0s - loss: 0.0959 - accuracy: 0.9398
# Epoch 00008: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0962 - accuracy: 0.9398
# Epoch 9/90
# 950/978 [============================>.] - ETA: 0s - loss: 0.0958 - accuracy: 0.9393
# Epoch 00009: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0954 - accuracy: 0.9394
# Epoch 10/90
# 951/978 [============================>.] - ETA: 0s - loss: 0.0927 - accuracy: 0.9425
# Epoch 00010: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0929 - accuracy: 0.9422
# Epoch 11/90
# 956/978 [============================>.] - ETA: 0s - loss: 0.0906 - accuracy: 0.9421
# Epoch 00011: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0901 - accuracy: 0.9427
# Epoch 12/90
# 957/978 [============================>.] - ETA: 0s - loss: 0.0899 - accuracy: 0.9449
# Epoch 00012: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0899 - accuracy: 0.9446
# Epoch 13/90
# 971/978 [============================>.] - ETA: 0s - loss: 0.0888 - accuracy: 0.9443
# Epoch 00013: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0886 - accuracy: 0.9444
# Epoch 14/90
# 946/978 [============================>.] - ETA: 0s - loss: 0.0874 - accuracy: 0.9461
# Epoch 00014: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0873 - accuracy: 0.9463
# Epoch 15/90
# 958/978 [============================>.] - ETA: 0s - loss: 0.0839 - accuracy: 0.9477
# Epoch 00015: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0840 - accuracy: 0.9474
# Epoch 16/90
# 964/978 [============================>.] - ETA: 0s - loss: 0.0846 - accuracy: 0.9465
# Epoch 00016: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0844 - accuracy: 0.9467
# Epoch 17/90
# 965/978 [============================>.] - ETA: 0s - loss: 0.0810 - accuracy: 0.9492
# Epoch 00017: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0813 - accuracy: 0.9491
# Epoch 18/90
# 954/978 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9503
# Epoch 00018: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0817 - accuracy: 0.9501
# Epoch 19/90
# 966/978 [============================>.] - ETA: 0s - loss: 0.0817 - accuracy: 0.9497
# Epoch 00019: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0822 - accuracy: 0.9497
# Epoch 20/90
# 968/978 [============================>.] - ETA: 0s - loss: 0.0789 - accuracy: 0.9511
# Epoch 00020: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0790 - accuracy: 0.9510
# Epoch 21/90
# 955/978 [============================>.] - ETA: 0s - loss: 0.0769 - accuracy: 0.9522
# Epoch 00021: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0769 - accuracy: 0.9519
# Epoch 22/90
# 949/978 [============================>.] - ETA: 0s - loss: 0.0769 - accuracy: 0.9522
# Epoch 00022: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0769 - accuracy: 0.9523
# Epoch 23/90
# 966/978 [============================>.] - ETA: 0s - loss: 0.0762 - accuracy: 0.9519
# Epoch 00023: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0765 - accuracy: 0.9518
# Epoch 24/90
# 956/978 [============================>.] - ETA: 0s - loss: 0.0726 - accuracy: 0.9541
# Epoch 00024: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0727 - accuracy: 0.9537
# Epoch 25/90
# 957/978 [============================>.] - ETA: 0s - loss: 0.0732 - accuracy: 0.9530
# Epoch 00025: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0733 - accuracy: 0.9531
# Epoch 26/90
# 951/978 [============================>.] - ETA: 0s - loss: 0.0737 - accuracy: 0.9531
# Epoch 00026: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0734 - accuracy: 0.9532
# Epoch 27/90
# 969/978 [============================>.] - ETA: 0s - loss: 0.0719 - accuracy: 0.9523
# Epoch 00027: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0717 - accuracy: 0.9524
# Epoch 28/90
# 967/978 [============================>.] - ETA: 0s - loss: 0.0725 - accuracy: 0.9533
# Epoch 00028: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0725 - accuracy: 0.9533
# Epoch 29/90
# 959/978 [============================>.] - ETA: 0s - loss: 0.0729 - accuracy: 0.9519
# Epoch 00029: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0725 - accuracy: 0.9523
# Epoch 30/90
# 978/978 [==============================] - ETA: 0s - loss: 0.0684 - accuracy: 0.9548
# Epoch 00030: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0684 - accuracy: 0.9548
# Epoch 31/90
# 963/978 [============================>.] - ETA: 0s - loss: 0.0711 - accuracy: 0.9544
# Epoch 00031: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0706 - accuracy: 0.9549
# Epoch 32/90
# 959/978 [============================>.] - ETA: 0s - loss: 0.0674 - accuracy: 0.9565
# Epoch 00032: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0682 - accuracy: 0.9561
# Epoch 33/90
# 973/978 [============================>.] - ETA: 0s - loss: 0.0670 - accuracy: 0.9547
# Epoch 00033: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0669 - accuracy: 0.9548
# Epoch 34/90
# 977/978 [============================>.] - ETA: 0s - loss: 0.0671 - accuracy: 0.9550
# Epoch 00034: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0671 - accuracy: 0.9550
# Epoch 35/90
# 963/978 [============================>.] - ETA: 0s - loss: 0.0648 - accuracy: 0.9564
# Epoch 00035: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0652 - accuracy: 0.9561
# Epoch 36/90
# 949/978 [============================>.] - ETA: 0s - loss: 0.0676 - accuracy: 0.9551
# Epoch 00036: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0676 - accuracy: 0.9553
# Epoch 37/90
# 958/978 [============================>.] - ETA: 0s - loss: 0.0641 - accuracy: 0.9575
# Epoch 00037: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0639 - accuracy: 0.9575
# Epoch 38/90
# 967/978 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9566
# Epoch 00038: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0632 - accuracy: 0.9565
# Epoch 39/90
# 954/978 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9583
# Epoch 00039: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0633 - accuracy: 0.9584
# Epoch 40/90
# 968/978 [============================>.] - ETA: 0s - loss: 0.0642 - accuracy: 0.9562
# Epoch 00040: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0642 - accuracy: 0.9560
# Epoch 41/90
# 948/978 [============================>.] - ETA: 0s - loss: 0.0615 - accuracy: 0.9584
# Epoch 00041: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0622 - accuracy: 0.9584
# Epoch 42/90
# 970/978 [============================>.] - ETA: 0s - loss: 0.0628 - accuracy: 0.9570
# Epoch 00042: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0625 - accuracy: 0.9573
# Epoch 43/90
# 954/978 [============================>.] - ETA: 0s - loss: 0.0652 - accuracy: 0.9559
# Epoch 00043: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0656 - accuracy: 0.9559
# Epoch 44/90
# 947/978 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9587
# Epoch 00044: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0602 - accuracy: 0.9589
# Epoch 45/90
# 949/978 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.9594
# Epoch 00045: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0613 - accuracy: 0.9592
# Epoch 46/90
# 974/978 [============================>.] - ETA: 0s - loss: 0.0582 - accuracy: 0.9620
# Epoch 00046: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0583 - accuracy: 0.9620
# Epoch 47/90
# 968/978 [============================>.] - ETA: 0s - loss: 0.0589 - accuracy: 0.9588
# Epoch 00047: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0586 - accuracy: 0.9590
# Epoch 48/90
# 948/978 [============================>.] - ETA: 0s - loss: 0.0596 - accuracy: 0.9592
# Epoch 00048: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0603 - accuracy: 0.9588
# Epoch 49/90
# 958/978 [============================>.] - ETA: 0s - loss: 0.0568 - accuracy: 0.9601
# Epoch 00049: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0570 - accuracy: 0.9601
# Epoch 50/90
# 972/978 [============================>.] - ETA: 0s - loss: 0.0595 - accuracy: 0.9594
# Epoch 00050: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0593 - accuracy: 0.9596
# Epoch 51/90
# 965/978 [============================>.] - ETA: 0s - loss: 0.0571 - accuracy: 0.9602
# Epoch 00051: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0573 - accuracy: 0.9602
# Epoch 52/90
# 967/978 [============================>.] - ETA: 0s - loss: 0.0579 - accuracy: 0.9610
# Epoch 00052: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0581 - accuracy: 0.9608
# Epoch 53/90
# 970/978 [============================>.] - ETA: 0s - loss: 0.0574 - accuracy: 0.9610
# Epoch 00053: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0574 - accuracy: 0.9610
# Epoch 54/90
# 950/978 [============================>.] - ETA: 0s - loss: 0.0559 - accuracy: 0.9597
# Epoch 00054: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0557 - accuracy: 0.9597
# Epoch 55/90
# 949/978 [============================>.] - ETA: 0s - loss: 0.0554 - accuracy: 0.9605
# Epoch 00055: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0554 - accuracy: 0.9605
# Epoch 56/90
# 950/978 [============================>.] - ETA: 0s - loss: 0.0595 - accuracy: 0.9584
# Epoch 00056: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0597 - accuracy: 0.9582
# Epoch 57/90
# 949/978 [============================>.] - ETA: 0s - loss: 0.0534 - accuracy: 0.9623
# Epoch 00057: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0532 - accuracy: 0.9623
# Epoch 58/90
# 955/978 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9633
# Epoch 00058: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0547 - accuracy: 0.9627
# Epoch 59/90
# 949/978 [============================>.] - ETA: 0s - loss: 0.0593 - accuracy: 0.9581
# Epoch 00059: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0592 - accuracy: 0.9581
# Epoch 60/90
# 949/978 [============================>.] - ETA: 0s - loss: 0.0557 - accuracy: 0.9627
# Epoch 00060: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0561 - accuracy: 0.9625
# Epoch 61/90
# 948/978 [============================>.] - ETA: 0s - loss: 0.0538 - accuracy: 0.9636
# Epoch 00061: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0542 - accuracy: 0.9635
# Epoch 62/90
# 955/978 [============================>.] - ETA: 0s - loss: 0.0547 - accuracy: 0.9611
# Epoch 00062: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0551 - accuracy: 0.9610
# Epoch 63/90
# 977/978 [============================>.] - ETA: 0s - loss: 0.0542 - accuracy: 0.9633
# Epoch 00063: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0542 - accuracy: 0.9632
# Epoch 64/90
# 956/978 [============================>.] - ETA: 0s - loss: 0.0547 - accuracy: 0.9629
# Epoch 00064: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0546 - accuracy: 0.9626
# Epoch 65/90
# 944/978 [===========================>..] - ETA: 0s - loss: 0.0539 - accuracy: 0.9614
# Epoch 00065: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0543 - accuracy: 0.9613
# Epoch 66/90
# 964/978 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9610
# Epoch 00066: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0550 - accuracy: 0.9608
# Epoch 67/90
# 961/978 [============================>.] - ETA: 0s - loss: 0.0505 - accuracy: 0.9646
# Epoch 00067: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0509 - accuracy: 0.9644
# Epoch 68/90
# 974/978 [============================>.] - ETA: 0s - loss: 0.0515 - accuracy: 0.9640
# Epoch 00068: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0514 - accuracy: 0.9641
# Epoch 69/90
# 960/978 [============================>.] - ETA: 0s - loss: 0.0538 - accuracy: 0.9648
# Epoch 00069: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0537 - accuracy: 0.9651
# Epoch 70/90
# 955/978 [============================>.] - ETA: 0s - loss: 0.0492 - accuracy: 0.9656
# Epoch 00070: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0494 - accuracy: 0.9652
# Epoch 71/90
# 949/978 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9618
# Epoch 00071: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0549 - accuracy: 0.9614
# Epoch 72/90
# 960/978 [============================>.] - ETA: 0s - loss: 0.0559 - accuracy: 0.9615
# Epoch 00072: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0562 - accuracy: 0.9615
# Epoch 73/90
# 948/978 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9628
# Epoch 00073: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 1s 2ms/step - loss: 0.0542 - accuracy: 0.9626
# Epoch 74/90
# 970/978 [============================>.] - ETA: 0s - loss: 0.0528 - accuracy: 0.9640
# Epoch 00074: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0528 - accuracy: 0.9640
# Epoch 75/90
# 957/978 [============================>.] - ETA: 0s - loss: 0.0551 - accuracy: 0.9627
# Epoch 00075: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0549 - accuracy: 0.9628
# Epoch 76/90
# 957/978 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9632
# Epoch 00076: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0519 - accuracy: 0.9628
# Epoch 77/90
# 969/978 [============================>.] - ETA: 0s - loss: 0.0516 - accuracy: 0.9634
# Epoch 00077: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0518 - accuracy: 0.9633
# Epoch 78/90
# 960/978 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9662
# Epoch 00078: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0488 - accuracy: 0.9664
# Epoch 79/90
# 973/978 [============================>.] - ETA: 0s - loss: 0.0511 - accuracy: 0.9642
# Epoch 00079: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0510 - accuracy: 0.9643
# Epoch 80/90
# 952/978 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9641
# Epoch 00080: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0525 - accuracy: 0.9637
# Epoch 81/90
# 961/978 [============================>.] - ETA: 0s - loss: 0.0484 - accuracy: 0.9683
# Epoch 00081: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0489 - accuracy: 0.9683
# Epoch 82/90
# 971/978 [============================>.] - ETA: 0s - loss: 0.0476 - accuracy: 0.9641
# Epoch 00082: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0478 - accuracy: 0.9641
# Epoch 83/90
# 968/978 [============================>.] - ETA: 0s - loss: 0.0506 - accuracy: 0.9642
# Epoch 00083: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0507 - accuracy: 0.9643
# Epoch 84/90
# 962/978 [============================>.] - ETA: 0s - loss: 0.0490 - accuracy: 0.9663
# Epoch 00084: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0487 - accuracy: 0.9664
# Epoch 85/90
# 971/978 [============================>.] - ETA: 0s - loss: 0.0491 - accuracy: 0.9664
# Epoch 00085: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0490 - accuracy: 0.9664
# Epoch 86/90
# 974/978 [============================>.] - ETA: 0s - loss: 0.0515 - accuracy: 0.9655
# Epoch 00086: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0515 - accuracy: 0.9654
# Epoch 87/90
# 972/978 [============================>.] - ETA: 0s - loss: 0.0482 - accuracy: 0.9684
# Epoch 00087: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0485 - accuracy: 0.9681
# Epoch 88/90
# 964/978 [============================>.] - ETA: 0s - loss: 0.0490 - accuracy: 0.9651
# Epoch 00088: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0491 - accuracy: 0.9652
# Epoch 89/90
# 964/978 [============================>.] - ETA: 0s - loss: 0.0483 - accuracy: 0.9673
# Epoch 00089: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0483 - accuracy: 0.9674
# Epoch 90/90
# 962/978 [============================>.] - ETA: 0s - loss: 0.0489 - accuracy: 0.9660
# Epoch 00090: saving model to keras_convnet_model.h5
# 978/978 [==============================] - 2s 2ms/step - loss: 0.0488 - accuracy: 0.9660
# Process completed in 139.87  seconds

# %% [markdown]
# # Save the Model

# %%
saveModel = False
if saveModel:
    cn_model.save('IMPROVETESTING_save')
    
    with open('IMPROVETESTING_save/median.properties', 'w+') as outhan:
        print(mean, std, file=outhan)
#    
#if save_model_iteration:
#    i = int(np.random.rand(1)*1000)
#    output_fn = f'TEST_model_saves/prod_save_{i}'
#    cn_model.save(output_fn)
#    print(f'\n   saved to {output_fn}\n')
#    with open(f'{output_fn}/median.properties','w+') as han:
#        print(f'{med, std, mean}', file=han)

# %% [markdown]
# # Validation
#
# Finally, we use the model trained above to make predictions on the test/validation sample. We then compare these predicted labels with the original ones, and derive a prediction accuracy.

# %%
preds_test = cn_model.predict(X_test, verbose=1)

preds_train = cn_model.predict(X_train, verbose=1)
# Out:
# 26/26 [==============================] - 0s 817us/step
# 489/489 [==============================] - 0s 638us/step

# %%
pyl.figure(figsize=(10,10))
pyl.hist(preds_train[:, 1], bins=200, density=True,alpha=0.5, label='Train', log=True)
pyl.hist(preds_test[:, 1], bins=200, density=True,alpha=0.5,label='Test', log=True)
pyl.legend()
pyl.show()

# %%
def Eff(m,  eff_max=0.8295, c=0.0054, M_0=26.3803,sig= 0.2016  ):
    return (eff_max-c*(m-21.0)**2)/(1+np.exp((m-M_0)/sig))

# measure the distribution of p values as a function of magnitude
eff_fig = pyl.figure('Efficiency Estimate', figsize=(12, 8))
eff_sp = eff_fig.add_subplot(111)
eff_sp.set_xlabel('r')
eff_sp.set_ylabel('e(r)')
                  
figure = pyl.figure('P-value histogram', figsize=(12, 12))
sp = figure.add_subplot(111)

good_p_value = 0.997
m_step = 0.25

print(len(np.where(preds_test>good_p_value)[0]))

bins = np.linspace(0.0,1.0,10000)
n_false = bins*0.0
n_found = 0.0
K = np.sum(np.less(bins,good_p_value))
n_bin_diff = 0
for m in np.arange(19.,28.,m_step):
    # plot the P-value cumulative distributions
    w = np.where( ((source_details[test_index, 5]-m)>=0) & ((source_details[test_index, 5]-m)<=m_step) )
    p_values = preds_test[w[0],1]
    
    n = bins*0.0
    k = ((p_values-bins[0])/(bins[1]-bins[0])).astype(np.int)
    for i in k:
        n[i:]+=1.0
    n_found+=n[-1]-n[K]
    n/=n[-1]
    
    
    # plot the efficiency curve estimate
    
    sp.plot(bins,n,label=f'{m}<=r<={m+m_step}')
    eff_sp.scatter(m+m_step/2.,1.0-n[K])
    if len(p_values)>0:
        print('{:.2f} {:.4f} {:.4f} {:.2f} {}'.format( m, np.min(p_values), np.max(p_values), 1.0-n[K], n_found-n_bin_diff ))
    n_bin_diff = n_found
    
eff_sp.plot(np.arange(19.,28.,m_step/10.),Eff(np.arange(19.,28.,m_step/10.)))

# now sum up the false positives
w = np.where( (source_details[test_index, 5])==0) 
p_values_false = preds_test[w[0],1]

k = ((p_values_false-bins[0])/(bins[1]-bins[0])).astype(np.int)
for i in k:
    n_false[:i]+=1.0

print()
print(f'Number of false-marked candidates with P>{good_p_value}:',np.sum(n_false[K:]))
print(f'Number of sources marked as real with P>{good_p_value}:',n_found)

n_false/=n_false[0]
pyl.plot(bins, n_false,'k:', lw=4)

eff_sp.grid()
    
pyl.plot([0, 1], [0.1, 0.1], 'k--')
pyl.plot([0, 1], [0.3, 0.3], 'k--')
pyl.plot([0, 1], [0.5, 0.5], 'k--')
pyl.plot([0, 1], [0.7, 0.7], 'k--')
pyl.plot([good_p_value, good_p_value], [0, 1], 'k:')
sp.legend()
sp.set_yscale('log')
sp.set_xlim(0.99,1.0)
pyl.xlabel('P(is real)')
pyl.ylabel('N(p<P)')
pyl.show()
# Out:
# 355
# 25.00 0.0016 0.9998 0.93 40.0
# 25.25 0.1015 0.9998 0.92 44.0
# 25.50 0.0025 0.9998 0.85 33.0
# 25.75 0.0281 0.9998 0.85 33.0
# 26.00 0.1717 0.9998 0.79 30.0
# 26.25 0.1324 0.9997 0.56 14.0
# 26.50 0.0908 0.9993 0.50 9.0
# 26.75 0.8018 0.9993 0.60 3.0
#
# Number of false-marked candidates with P>0.997: 60.0
# Number of sources marked as real with P>0.997: 206.0
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide

# %%
preds_test_t = (preds_test > 0.5).astype(np.uint8)




X_test_plot = np.squeeze(X_test, axis=4)
X_train_plot = np.squeeze(X_train, axis=4)

print('Fraction of correct predictions: ', round(accuracy_score(y_test, preds_test_t), 3))

cut = make_display_image(X_test_plot[-1], 3)
pyl.imshow(cut, origin='lower')
pyl.show()


"""
for i in range(len(preds_test)):
    if y_test[i][1] == 1 and preds_test[i][1]>0.05:
        cut = make_display_image(X_test_plot[i])
        pyl.imshow(cut, origin='lower')
        pyl.title('Orig:' + str(y_test[i]) + '| Pred:' + str(preds_test[i])+' '+str(source_details[test_index[i]]))
        pyl.show()
print('next')
"""

"""
n=0
for i in range(len(preds_train)):
    if y_train[i][1] == 1 and preds_train[i][1]>0.5 and source_details[train_index[i]][2]>=25:
        cut = make_display_image(X_train_plot[i])
        pyl.imshow(cut, origin='lower')
        pyl.title('Orig:' + str(y_train[i]) + '| Pred:' + str(preds_train[i])+' '+str(source_details[train_index[i]]))
        pyl.show()
        n+=1

print(n,len(preds_test))
"""

"""
print('next next')
for i in range(len(preds_train)):
    if y_train[i][1] == 0 and preds_train[i][1]>0.95:
        cut = make_display_image(X_train_plot[i])
        pyl.imshow(cut, origin='lower')
        pyl.title('Orig:' + str(y_train[i]) + '| Pred:' + str(preds_train[i])+' '+str(source_details[train_index[i]]))
        pyl.show()
for i in range(len(preds_test)):
    if y_test[i][1] == 0 and preds_test[i][1]>0.95:
        cut = make_display_image(X_test_plot[i])
        pyl.imshow(cut, origin='lower')
        pyl.title('Orig:' + str(y_test[i]) + '| Pred:' + str(preds_test[i])+' '+str(source_details[test_index[i]]))
        pyl.show()

"""
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-17-913019d57182> in <module>()
#       4
#       5
# ----> 6 X_test_plot = np.squeeze(X_test, axis=4)
#       7 X_train_plot = np.squeeze(X_train, axis=4)
#       8
#
# <__array_function__ internals> in squeeze(*args, **kwargs)
#
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/numpy/core/fromnumeric.py in squeeze(a, axis)
#    1493         return squeeze()
#    1494     else:
# -> 1495         return squeeze(axis=axis)
#    1496
#    1497
#
# AxisError: axis 4 is out of bounds for array of dimension 4
