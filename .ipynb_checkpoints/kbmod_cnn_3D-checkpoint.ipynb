# %% [markdown]
# # MOPS for KBmod
#
# Based off the CNN developed for the first ML search of the New Horizons 2020 search

# %%
import os, glob, sys
import time

import random
"""Import the basics: numpy, pandas, matplotlib, etc."""
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyl
import matplotlib.gridspec as gridspec
import pickle
"""Import keras and other ML tools"""
import tensorflow as tf
import keras

from keras.models import Model, load_model, Sequential
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv3D, Conv2D, MaxPool3D
from keras.layers.core import Dropout, Lambda
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
"""Import scikit learn tools"""
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.utils.multiclass import unique_labels
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
"""Import astropy libraries"""
from astropy.io import fits
from astropy import wcs
from astropy.nddata import Cutout2D
from astropy.visualization import interval

from trippy import tzscale
from trippy.trippy_utils import expand2d, downSample2d

from convenience_utils import calc_ecliptic_angle

from utils import shuffle

# %%
"""These are some of the flags."""
visits = ['03093']

image_data_type = 'float32'

batch_size = 16 # production used 128
dropout_rate = 0.2
test_fraction = 0.05
select_bad_at_random = True
badGoodRatio = 0.8*5.0#1.5
bad_edge_enhancement = 0.002
useMedForNans = False #otherwise zero is used
useZscale = False


shuffle_augment = False # shuffle bootstrapping augmentation
double_flip = False # mirror vertically augmentation
add_noise = False
noise_level=3.0


nukeFaint = 27.1 # if set to a real value, all fainter planted source associations will be set to false
dist_lim = 3.5 #association to planted source
save_model_iteration = False

useSampleWeights = True

useTripletGrids = True

# %% [markdown]
# # Data Exploration
#
# First read in the data, and make it look like the data from the tutorial

# %%
chips = []
#for i in range(103,-1,-1):
for i in range(104):
    if i==9: continue
    if i in [89]: continue
    chips.append(str(i).zfill(3))
#chips = ['031','050']
    

# load the data
sns_frames = []
n_edge_added = 0
n_bad_total = 0

reference_fits_images = []
ecl_angles = []
stamp_files = []
kb_xys,fs = [],[]
for i, c in enumerate(chips):
    for j, v in enumerate(visits):
        warps_path = f'/media/fraserw/rocketdata/Projects/kbmod/DATA/rerun/diff_warpCompare/deepDiff/{v}/HSC-R2/warps'
        reference_fits_images.append(glob.glob(f'{warps_path}/{c}/DIFFEXP*fits')[0])
        ecl_ang = calc_ecliptic_angle(reference_fits_images[-1])
        ecl_angles.append(ecl_ang)
        if c=='050':
            ref_ecl_ang = ecl_ang
ecl_angles = np.array(ecl_angles)
rots = (ref_ecl_ang-ecl_angles)*180./np.pi

corners = np.array([-270., -180., -90., 0., 90., 180., 270.])
for i,r in enumerate(rots):
    rot = corners[np.argmin(np.abs(r-corners))]
    if rot<0: 
        rot+=360.
    print(chips[i],r,rot)
    rots[i] = rot/90.
rots = rots.astype(np.int)
# Out:
# 000 -1.1873518094705156 0.0
# 001 -0.0983170107051293 0.0
# 002 0.8732897447223871 0.0
# 003 1.8149020476100624 0.0
# 004 -2.128106320589695 0.0
# 005 -1.0330049643741732 0.0
# 006 -0.16468738397494367 0.0
# 007 0.6656933616781258 0.0
# 008 1.362004999304686 0.0
# 010 -1.7540284872212881 0.0
# 011 -0.812419793655703 0.0
# 012 -0.18529351865103108 0.0
# 013 0.4215696466448263 0.0
# 014 1.0580325195978442 0.0
# 015 1.6075196750457097 0.0
# 016 178.5772997679311 180.0
# 017 179.2862520779912 180.0
# 018 179.83120203398212 180.0
# 019 0.31637972925577074 0.0
# 020 0.7230417975202774 0.0
# 021 1.2052765347968464 0.0
# 022 178.12505072042373 180.0
# 023 178.93493202966974 180.0
# 024 179.46920773584995 180.0
# 025 179.86753423493022 180.0
# 026 0.1803312119487925 0.0
# 027 0.49483349339207744 0.0
# 028 0.7808845872487353 0.0
# 029 1.0110437165039496 0.0
# 030 178.6295674629541 180.0
# 031 179.18064437702358 180.0
# 032 179.60180131008576 180.0
# 033 179.90130291089628 180.0
# 034 0.08349784126086654 0.0
# 035 0.23389231219916995 0.0
# 036 0.3791428877791761 0.0
# 037 0.45883435217175617 0.0
# 038 179.08559038652277 180.0
# 039 179.4660937419479 180.0
# 040 179.7362818477422 180.0
# 041 179.91678913818325 180.0
# 042 0.03110332342953257 0.0
# 043 0.07978953138348958 0.0
# 044 0.06132229706474332 0.0
# 045 -0.03327008418699437 0.0
# 046 179.53989344168804 180.0
# 047 179.78597687714574 180.0
# 048 179.89971297935733 180.0
# 049 179.9647059478439 180.0
# 050 0.0 0.0
# 051 -0.06612749377051604 0.0
# 052 -0.2831469854606121 0.0
# 053 -0.4989765553868084 0.0
# 054 180.00370785115453 180.0
# 055 180.05255562323595 180.0
# 056 180.07842791127192 180.0
# 057 179.98444854058195 180.0
# 058 -0.09511095945257185 0.0
# 059 -0.29186231397279727 0.0
# 060 -0.5621533940642037 0.0
# 061 -0.9690277814368262 0.0
# 062 180.5339144451557 180.0
# 063 180.40719134173273 180.0
# 064 180.26120712275798 180.0
# 065 180.09395187938986 180.0
# 066 -0.13979330599933365 0.0
# 067 -0.4534522436673279 0.0
# 068 -0.8477733387145665 0.0
# 069 -1.480168400314408 0.0
# 070 180.99672950736579 180.0
# 071 180.75943937289068 180.0
# 072 180.4899758344846 180.0
# 073 180.20639703273815 180.0
# 074 -0.1561515902566882 0.0
# 075 -0.5950504631612227 0.0
# 076 -1.1704457015644054 0.0
# 077 -1.9505123499686778 0.0
# 078 181.20700651368398 180.0
# 079 180.75655706524998 180.0
# 080 180.291840962031 180.0
# 081 -0.1811012313945933 0.0
# 082 -0.7240957296290679 0.0
# 083 -1.4501333668808405 0.0
# 084 181.6726418811617 180.0
# 085 181.0356514654751 180.0
# 086 180.4319211244366 180.0
# 087 179.78208847696496 180.0
# 088 179.06607995125694 180.0
# 090 182.19248452163427 180.0
# 091 181.40311294258328 180.0
# 092 180.60974232259076 180.0
# 093 179.8033346078976 180.0
# 094 178.92352957351585 180.0
# 095 177.78049089678555 180.0
# 096 181.79740528675651 180.0
# 097 180.83631905542768 180.0
# 098 179.81888100255168 180.0
# 099 178.6983112457994 180.0
# 100 87.64834938393693 90.0
# 101 91.78855114426017 90.0
# 102 -88.16007049910112 270.0
# 103 -92.42072683589257 270.0

# %%
gridType = ''
if useTripletGrids:
    gridType = '_tg'
    
counter = 0
for i, c in enumerate(chips):
    for j, v in enumerate(visits):
        warps_path = f'/media/fraserw/rocketdata/Projects/kbmod/DATA/rerun/diff_warpCompare/deepDiff/{v}/HSC-R2/warps'
        reference_fits_images.append(glob.glob(f'{warps_path}/{c}/DIFFEXP*fits')[0])

        stamp_files.append(f'{warps_path}/stamps{gridType}_{c}.pickle')

        
        #get the image header and setup a WCS
        with fits.open(reference_fits_images[-1]) as han:
            header = han[1].header
            (A,B) = han[1].data.shape
            
        im_wcs = wcs.WCS(header)

        
        #load the kbmod results
        kb_xy = []
        with open(f'/media/fraserw/rocketdata/Projects/kbmod/warps_results/results_{c}_lower/results_LOWER.txt') as han:
            data = han.readlines()
        with open(f'/media/fraserw/rocketdata/Projects/kbmod/warps_results/results_{c}_upper/results_UPPER.txt') as han:
            data += han.readlines()

        for ii in range(len(data)):
            s = data[ii].split()
            x, y = float(s[5]), float(s[7])
            repeat = False
            for jj in range(len(kb_xy)):
                if kb_xy[jj][0]==x and kb_xy[jj][1]==y:
                    repeat = True
                    break
            if not repeat:
                kb_xy.append([float(s[5]) , float(s[7]) , float(s[9]), float(s[11]), float(s[1]), 0.0])
        kb_xy = np.array(kb_xy)
        #print(kb_xy[0])
        
        #load the plantlist sources
        p_xy = []
        with open(f'/media/fraserw/rocketdata/Projects/ML_SNS_MOPS/HSC_June19-lsst/rerun/processCcdOutputs/03093/HSC-R2/corr/planted/CORR-0220262-{c}.plantList') as han:
            data = han.readlines()
        for ii in range(1,len(data)):
            s = data[ii].split()
            ra,dec = float(s[1]), float(s[2])
            coord = np.array(im_wcs.all_world2pix(ra, dec, 0))

            x,y = coord[0],coord[1]
            #x = float(s[3]) + offsets[c][0]
            #y = float(s[4]) + offsets[c][1]
            repeat = False
            for jj in range(len(p_xy)):
                if p_xy[jj][0] == x and p_xy[jj][1]==y:
                    p_xy[jj][2]-=0.75
                    repeat = True

            if not repeat:
                p_xy.append([x, y, float(s[9]), 0])
                
        if len(p_xy)>0:
            p_xy = np.array(p_xy)
            p_xy = p_xy[np.argsort(p_xy[:,2])]
            p_xy = p_xy[np.where(p_xy[:,2]<nukeFaint)]

            #label the good and bad sources
            for ii in range(len(p_xy)):
                d = ((p_xy[ii, 0] - kb_xy[:, 0])**2 + (p_xy[ii, 1] - kb_xy[:, 1])**2 )**0.5
                args = np.argsort(d)

                if d[args[0]]<dist_lim:
                    kb_xy[args[0],-1] = p_xy[ii,2]
                    #print(kb_xy[args[0]])
                    
        w_bad = np.where(kb_xy[:,-1]==0)
        w_good = np.where(kb_xy[:,-1]>0)
        print(v, c, len(w_bad[0]), len(w_good[0]), len(kb_xy))

        #load the stamps
        with open(stamp_files[-1], 'rb') as han:
            f = pickle.load(han)

            
        n_good = len(w_good[0])
        
        n_bad_keep = max(1, int(n_good*badGoodRatio))
        if n_bad_keep>0:
            if not select_bad_at_random:
                # sequential selection
                step = int(len(w[0])/n_bad_keep)
                w = w_bad[0][np.arange(0,len(w_bad[0]),step)]
            else:
                # random selection
                w = w_bad[0][(np.random.rand(n_bad_keep)*len(w_bad[0])).astype(np.int)]

        # add edge bad sources
        if bad_edge_enhancement>0:
            NN = 0
            w_edge = np.where((kb_xy[:, -1] ==0) & ((kb_xy[:,0]<25) | ((B-kb_xy[:,0])<20) | (kb_xy[:, 1]<25) | ((A-kb_xy[:,1])<20)))
            n_edge_bad_keep = int(len(w_edge[0])*bad_edge_enhancement)
            while NN<n_edge_bad_keep:
                j = int(np.random.rand(1)*len(w_edge[0]))
                if j not in w:
                    w = np.append(w, j)
                    NN += 1
        n_edge_added+=NN
        n_bad_total += len(w)
        
        w = np.concatenate([w, w_good[0]])
        
        
        print('Number good, bad, and number edge enhanced:', n_good, n_bad_keep, n_edge_bad_keep)

        f = f[w]
        kb_xy = kb_xy[w]

        #rotate frames
        #k should be -rots!
        if rots[counter]!=0:
            f = np.rot90(f, k=-rots[counter], axes=(2, 3))
        counter+=1
        
        
        fs.append(f)
        kb_xys.append(kb_xy)
        del f, kb_xy

        


source_details = np.concatenate(kb_xys)
sns_frames = np.concatenate(fs)
print(sns_frames.shape)
del kb_xys
del fs
    
print('Number of bad edge sources added:',n_edge_added)
print(f'Number of total bad sources in sample {n_bad_total}')
# Out:
# 03093 000 2600 17 2617
# Number good, bad, and number edge enhanced: 17 68 0
# 03093 001 4346 18 4364
# Number good, bad, and number edge enhanced: 18 72 0
# 03093 002 4242 26 4268
# Number good, bad, and number edge enhanced: 26 104 0
# 03093 003 4008 31 4039
# Number good, bad, and number edge enhanced: 31 124 0
# 03093 004 2986 15 3001
# Number good, bad, and number edge enhanced: 15 60 0
# 03093 005 3643 31 3674
# Number good, bad, and number edge enhanced: 31 124 0
# 03093 006 3874 42 3916
# Number good, bad, and number edge enhanced: 42 168 0
# 03093 007 3886 26 3912
# Number good, bad, and number edge enhanced: 26 104 0
# 03093 008 3856 28 3884
# Number good, bad, and number edge enhanced: 28 112 0
# 03093 010 4188 20 4208
# Number good, bad, and number edge enhanced: 20 80 0
# 03093 011 4180 28 4208
# Number good, bad, and number edge enhanced: 28 112 0
# 03093 012 3818 29 3847
# Number good, bad, and number edge enhanced: 29 116 0
# 03093 013 3479 32 3511
# Number good, bad, and number edge enhanced: 32 128 0
# 03093 014 3489 33 3522
# Number good, bad, and number edge enhanced: 33 132 0
# 03093 015 4172 50 4222
# Number good, bad, and number edge enhanced: 50 200 0
# 03093 016 3939 34 3973
# Number good, bad, and number edge enhanced: 34 136 0
# 03093 017 3871 27 3898
# Number good, bad, and number edge enhanced: 27 108 0
# 03093 018 3569 36 3605
# Number good, bad, and number edge enhanced: 36 144 0
# 03093 019 3429 28 3457
# Number good, bad, and number edge enhanced: 28 112 0
# 03093 020 3963 29 3992
# Number good, bad, and number edge enhanced: 29 116 0
# 03093 021 4194 47 4241
# Number good, bad, and number edge enhanced: 47 188 0
# 03093 022 2919 17 2936
# Number good, bad, and number edge enhanced: 17 68 0
# 03093 023 3650 25 3675
# Number good, bad, and number edge enhanced: 25 100 0
# 03093 024 4256 34 4290
# Number good, bad, and number edge enhanced: 34 136 0
# 03093 025 3317 33 3350
# Number good, bad, and number edge enhanced: 33 132 0
# 03093 026 3425 29 3454
# Number good, bad, and number edge enhanced: 29 116 0
# 03093 027 3600 38 3638
# Number good, bad, and number edge enhanced: 38 152 0
# 03093 028 3799 65 3864
# Number good, bad, and number edge enhanced: 65 260 0
# 03093 029 2760 28 2788
# Number good, bad, and number edge enhanced: 28 112 0
# 03093 030 3783 21 3804
# Number good, bad, and number edge enhanced: 21 84 0
# 03093 031 3937 30 3967
# Number good, bad, and number edge enhanced: 30 120 0
# 03093 032 3899 31 3930
# Number good, bad, and number edge enhanced: 31 124 0
# 03093 033 1713 26 1739
# Number good, bad, and number edge enhanced: 26 104 0
# 03093 034 3276 23 3299
# Number good, bad, and number edge enhanced: 23 92 0
# 03093 035 3638 39 3677
# Number good, bad, and number edge enhanced: 39 156 0
# 03093 036 3941 51 3992
# Number good, bad, and number edge enhanced: 51 204 0
# 03093 037 3921 38 3959
# Number good, bad, and number edge enhanced: 38 152 0
# 03093 038 3953 20 3973
# Number good, bad, and number edge enhanced: 20 80 0
# 03093 039 3468 36 3504
# Number good, bad, and number edge enhanced: 36 144 0
# 03093 040 3813 30 3843
# Number good, bad, and number edge enhanced: 30 120 0
# 03093 041 3148 29 3177
# Number good, bad, and number edge enhanced: 29 116 0
# 03093 042 3698 37 3735
# Number good, bad, and number edge enhanced: 37 148 0
# 03093 043 2819 24 2843
# Number good, bad, and number edge enhanced: 24 96 0
# 03093 044 4081 68 4149
# Number good, bad, and number edge enhanced: 68 272 0
# 03093 045 4278 47 4325
# Number good, bad, and number edge enhanced: 47 188 0
# 03093 046 4131 28 4159
# Number good, bad, and number edge enhanced: 28 112 0
# 03093 047 3723 27 3750
# Number good, bad, and number edge enhanced: 27 108 0
# 03093 048 3594 30 3624
# Number good, bad, and number edge enhanced: 30 120 0
# 03093 049 3365 34 3399
# Number good, bad, and number edge enhanced: 34 136 0
# 03093 050 3609 38 3647
# Number good, bad, and number edge enhanced: 38 152 0
# 03093 051 3917 28 3945
# Number good, bad, and number edge enhanced: 28 112 0
# 03093 052 3879 56 3935
# Number good, bad, and number edge enhanced: 56 224 0
# 03093 053 4238 44 4282
# Number good, bad, and number edge enhanced: 44 176 0
# 03093 054 3841 14 3855
# Number good, bad, and number edge enhanced: 14 56 0
# 03093 055 3833 23 3856
# Number good, bad, and number edge enhanced: 23 92 0
# 03093 056 3866 29 3895
# Number good, bad, and number edge enhanced: 29 116 0
# 03093 057 3503 22 3525
# Number good, bad, and number edge enhanced: 22 88 0
# 03093 058 3778 26 3804
# Number good, bad, and number edge enhanced: 26 104 0
# 03093 059 3037 6 3043
# Number good, bad, and number edge enhanced: 6 24 0
# 03093 060 4266 45 4311
# Number good, bad, and number edge enhanced: 45 180 0
# 03093 061 4601 34 4635
# Number good, bad, and number edge enhanced: 34 136 0
# 03093 062 3846 5 3851
# Number good, bad, and number edge enhanced: 5 20 0
# 03093 063 3818 34 3852
# Number good, bad, and number edge enhanced: 34 136 0
# 03093 064 3885 23 3908
# Number good, bad, and number edge enhanced: 23 92 0
# 03093 065 3573 37 3610
# Number good, bad, and number edge enhanced: 37 148 0
# 03093 066 4259 26 4285
# Number good, bad, and number edge enhanced: 26 104 0
# 03093 067 4002 25 4027
# Number good, bad, and number edge enhanced: 25 100 0
# 03093 068 4410 53 4463
# Number good, bad, and number edge enhanced: 53 212 0
# 03093 069 4087 45 4132
# Number good, bad, and number edge enhanced: 45 180 0
# 03093 070 3274 0 3274
# Number good, bad, and number edge enhanced: 0 1 0
# 03093 071 3951 23 3974
# Number good, bad, and number edge enhanced: 23 92 0
# 03093 072 3797 30 3827
# Number good, bad, and number edge enhanced: 30 120 0
# 03093 073 3843 36 3879
# Number good, bad, and number edge enhanced: 36 144 0
# 03093 074 3625 30 3655
# Number good, bad, and number edge enhanced: 30 120 0
# 03093 075 4083 30 4113
# Number good, bad, and number edge enhanced: 30 120 0
# 03093 076 4434 47 4481
# Number good, bad, and number edge enhanced: 47 188 0
# 03093 077 3611 32 3643
# Number good, bad, and number edge enhanced: 32 128 0
# 03093 078 4118 3 4121
# Number good, bad, and number edge enhanced: 3 12 0
# 03093 079 4160 32 4192
# Number good, bad, and number edge enhanced: 32 128 0
# 03093 080 3944 33 3977
# Number good, bad, and number edge enhanced: 33 132 0
# 03093 081 4012 26 4038
# Number good, bad, and number edge enhanced: 26 104 0
# 03093 082 3887 25 3912
# Number good, bad, and number edge enhanced: 25 100 0
# 03093 083 4549 45 4594
# Number good, bad, and number edge enhanced: 45 180 0
# 03093 084 4072 0 4072
# Number good, bad, and number edge enhanced: 0 1 0
# 03093 085 4244 15 4259
# Number good, bad, and number edge enhanced: 15 60 0
# 03093 086 4062 33 4095
# Number good, bad, and number edge enhanced: 33 132 0
# 03093 087 3959 33 3992
# Number good, bad, and number edge enhanced: 33 132 0
# 03093 088 3748 25 3773
# Number good, bad, and number edge enhanced: 25 100 0
# 03093 090 2920 0 2920
# Number good, bad, and number edge enhanced: 0 1 0
# 03093 091 4375 0 4375
# Number good, bad, and number edge enhanced: 0 1 0
# 03093 092 4197 9 4206
# Number good, bad, and number edge enhanced: 9 36 0
# 03093 093 3741 31 3772
# Number good, bad, and number edge enhanced: 31 124 0
# 03093 094 3185 22 3207
# Number good, bad, and number edge enhanced: 22 88 0
# 03093 095 3260 12 3272
# Number good, bad, and number edge enhanced: 12 48 0
# 03093 096 4058 0 4058
# Number good, bad, and number edge enhanced: 0 1 0
# 03093 097 4204 0 4204
# Number good, bad, and number edge enhanced: 0 1 0
# 03093 098 4190 20 4210
# Number good, bad, and number edge enhanced: 20 80 0
# 03093 099 4096 17 4113
# Number good, bad, and number edge enhanced: 17 68 0
# 03093 100 2179 11 2190
# Number good, bad, and number edge enhanced: 11 44 0
# 03093 101 2348 19 2367
# Number good, bad, and number edge enhanced: 19 76 0
# 03093 102 2472 0 2472
# Number good, bad, and number edge enhanced: 0 1 0
# 03093 103 2514 23 2537
# Number good, bad, and number edge enhanced: 23 92 0
# (14207, 9, 21, 21)
# Number of bad edge sources added: 0
# Number of total bad sources in sample 11367

# %%
if useMedForNans:
    med = np.nanmedian(sns_frames)
else:
    med = 0.0
    
w_nan = np.where(np.isnan(sns_frames))
sns_frames[w_nan] = med


# categorize the sources.
# column 0 is bad source. Labelled when ==1
# column 1 is good source
sns_labels = np.zeros((source_details[:, 5].shape[0], 2), dtype=image_data_type)
w = np.where(source_details[:, -1]==0)
W = np.where((source_details[:, -1]>0))
print('Number of planted sources in the dataset:', len(W[0]))
sns_labels[w, 0] = 1.0
sns_labels[W, 1] = 1.0


(z1, z2) = tzscale.zscale(sns_frames)
normer = interval.ManualInterval(z1,z2)

mean = np.mean(sns_frames)
std = np.std(sns_frames)
print(mean, std)

sns_frames -= mean
sns_frames /= std
print('Normalized frame min and max:', np.nanmin(sns_frames), np.nanmax(sns_frames))


# expand the image data to shape (:, :, :, 1) for the CNN
#sns_frames = np.expand_dims(sns_frames, axis=3)
sns_frames = np.expand_dims(sns_frames, axis=4)
print(sns_frames.shape)
# Out:
# Number of planted sources in the dataset: 2840
# 2.9604409 34.02412
# Normalized frame min and max: -22.16798 200.92569
# (14207, 9, 21, 21, 1)

# %%
if shuffle_augment:
    new_frames = shuffle(sns_frames)
    print(new_frames.shape)
    sns_frames = np.concatenate([sns_frames, new_frames])
    sns_labels = np.concatenate([sns_labels, np.copy(sns_labels)])
    source_details = np.concatenate([source_details, np.copy(source_details)])


if double_flip:
    normed_sns_frames = np.concatenate([normed_sns_frames, normed_sns_frames[:, :, ::-1, :, :]])
    sns_labels = np.concatenate([sns_labels, sns_labels])
    source_details = np.concatenate([source_details, source_details])
    
    
if add_noise:
    noise = np.random.normal(0.0, noise_level, sns_frames.shape).astype(image_data_type)
    #noised_sns_frames = normed_sns_frames + np.random.normal(0.0, noise_level, normed_sns_frames.shape, dtype=image_data_type)
    sns_frames = np.concatenate([sns_frames, sns_frames+noise])
    sns_labels = np.concatenate([sns_labels, sns_labels])
    source_details = np.concatenate([source_details, source_details])
    #del noised_sns_frames
    del noise
    mean = np.mean(sns_frames)
    std = np.std(sns_frames)
    print(mean, std)

    sns_frames -= mean
    sns_frames /= std
# Out:
# -6.1494604e-05 2.345044

# %%
print('Faintest source in dataset:', np.max(source_details[:, -1]))
# Out:
# Faintest source in dataset: 27.08

# %% [markdown]
# # Training and Test/Validation Samples
#
# In this part we will split our sample into two; one sample that we will use to train the neural network, aptly named the training sample, and another sample called the test sample. The network will not see the test sample itself during training, but we will use the trained neural network to predict its labels. It will therefore serve as validation to the accuracy of the neural network that has been trained using a different subset of images. We chose to set the size of the test sample as 15% of the total sample, as it is common practice to choose a test sample smaller in size compared to the training sample. It is important to make this split by roughly preserving the ratio of the labels within the total sample. Random splits may cause one of the labels to be underrepresented within training sample, thereby resulting in a neural network inacapable of accurate classifications as it is undertrained in one of the labels. We perform a stratified sampling below to preserve the original ratios of the two morphology types when making the split.
#
# I have modified the following to work with my data arrays, not those from the tutorial

# %%
"""
Use stratification to split the data into training & test samples.
This preserves the ratio of class 0 to class 1 objects when we split the
total sample into training and test samples. We choose the test sample to be 15%
of the total sample size.
"""

skf = StratifiedShuffleSplit(n_splits=1, test_size=test_fraction, random_state=41)
print(skf)
skf.split(sns_frames, sns_labels)


for train_index, test_index in skf.split(sns_frames, sns_labels):
    X_train, X_test = sns_frames[train_index], sns_frames[test_index]
    y_train, y_test = sns_labels[train_index], sns_labels[test_index]

#del sns_frames


print('Number of images in the training sample: ', X_train.shape[0])
print('Number of objects classified as real in the training sample: ',
      len(np.unique(np.where(y_train == [0, 1])[0])))
print('Number of objects classified as false in the training sample: ',
      len(np.unique(np.where(y_train == [1, 0])[0])))
print()
print('Number of images in the test sample: ', X_test.shape[0])
print('Number of objects classified as real in the validation sample: ',
      len(np.unique(np.where(y_test == [0, 1])[0])))
print('Number of objects classified as false in the validation sample: ',
      len(np.unique(np.where(y_test == [1, 0])[0])))
print()
print('Fraction of bad objects in the training sample',
      round((np.count_nonzero(y_train == [1, 0])/2)/X_train.shape[0], 3))

move_real_to_test = False
# remove the real source from the training set as a test to see what happens
if args[0] in train_index and move_real_to_test:
    w = np.where(train_index == args[0])

    print(X_train[w[0], 0, 0, 0])
    print(y_train[w[0]])
    
    X_test = np.concatenate([X_test, X_train[w[0]]])
    y_test = np.concatenate([y_test, y_train[w[0]]])
    test_index = np.append(test_index, [args[0]], -1)
    
    X_train = np.concatenate([X_train[:w[0][0]], X_train[w[0][0]+1:]])
    y_train = np.concatenate([y_train[:w[0][0]], y_train[w[0][0]+1:]])
    train_index = np.concatenate([train_index[:w[0][0]], train_index[w[0][0]+1:]])
    print(X_train.shape)
    print(y_train.shape)
    print(train_index.shape)
    print(X_test.shape)
    print(X_train[w[0][0],0, 0, 0])
    print(y_train[w[0]])
    print()
    print(X_test[-1, 0, 0, 0])
#w = np.where(train_index == args[0])
#y_train[w[0]][0] = 0.0
#y_train[w[0]][0] = 1.0
# Out:
# StratifiedShuffleSplit(n_splits=1, random_state=41, test_size=0.05,
#             train_size=None)
# Number of images in the training sample:  26993
# Number of objects classified as real in the training sample:  5396
# Number of objects classified as false in the training sample:  21597
#
# Number of images in the test sample:  1421
# Number of objects classified as real in the validation sample:  284
# Number of objects classified as false in the validation sample:  1137
#
# Fraction of bad objects in the training sample 0.8

# %%
if useSampleWeights:
    n_false_total = len(np.where(y_train[:,0]==1)[0]) + len(np.where(y_test[:,0]==1)[0])
    n_true_total = len(np.where(y_train[:,1]==1)[0]) + len(np.where(y_test[:,1]==1)[0])
    print('Fraction of good to bad sources:',n_true_total/n_false_total)
    
    true_weight = 1.0
    nominal_false_weight = 0.83
    false_weight = n_true_total*nominal_false_weight/n_false_total
    print('False weight:' , false_weight)
    
    train_weight = np.ones(y_train.shape[0], dtype = y_train.dtype)
    train_weight[np.where(y_train[:,0]==1)] = false_weight
    train_weight[np.where(y_train[:,1]==1)] = true_weight
    test_weight = np.ones(y_test.shape[0], dtype = y_train.dtype)
    test_weight[np.where(y_test[:,0]==1)] = false_weight
    test_weight[np.where(y_test[:,1]==1)] = true_weight
# Out:
# Fraction of good to bad sources: 0.24984604557051113
# False weight: 0.20737221782352422

# %% [markdown]
# # The Neural Network Model
#
# Below we define the neural network model we use for this task. This is a particularly and deliberately simple model. It consists only of convolution blocks (see introductory presentation), dropout layers, and dense layers as the final layers of the network to produce predictions. Dropout randomly ignores nodes within the network, in an effort to prevent overfitting. It becomes especially useful in small training samples, or inhomogeneous ones such as this case.
#
# The filters value is the number of separate kernels, each of size kernel_size that are created. In that sense, the .add(Conv2d()) line is adding a full network layer
#
# Flatten() reshapes the array to 1xn shape.
#
# Dense() sets up a normal hidden layer network.
#
# So in the example, we add two normal layers, the second one with output of two separate labels, as defined in unique_labs.

# %%
"""The 3D convolutional neural network model modified by Wes"""
# the one wes is tinkering with

def convnet_model(input_shape, training_labels, dropout_rate=dropout_rate):

    unique_labs = len(np.unique(training_labels))

    model = Sequential()

    # it seems having 2 hiddne layers of filter#=16 and max pooling between each does better than the version below
    #hidden layer 1 with Pooling
    """
    model.add(Conv3D(filters=16, kernel_size=(3, 3, 1), input_shape=input_shape, activation='relu', padding='same'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPool3D(pool_size=(2, 2, 2), padding='valid'))

    #hidden layer 2 with Pooling
    model.add(Conv3D(filters=16, kernel_size=(3, 3, 1), input_shape=input_shape, activation='relu', padding='same'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPool3D(pool_size=(2, 2, 2), padding='valid'))
    
    model.add(Flatten())
    model.add(Dense(128, activation='sigmoid'))
    model.add(Dense(unique_labs, activation='softmax'))
    
    """

    ### for prodcution I used 16,16,8. 
    ### testing to see if I can fit bigger
    #hidden layer 1 
    model.add(Conv3D(filters=32, kernel_size=(1, 3, 3), input_shape=input_shape, activation='relu', padding='same'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPool3D(pool_size=(2, 2, 2), padding='valid'))

    #hidden layer 2 with Pooling
    model.add(Conv3D(filters=32, kernel_size=(1, 3, 3), input_shape=input_shape, activation='relu', padding='same'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPool3D(pool_size=(2, 2, 2), padding='valid'))
    
    model.add(BatchNormalization())
    
    #hidden layer 3 with Pooling
    model.add(Conv3D(filters = 32, kernel_size=(1, 3, 3), input_shape=input_shape, activation='relu', padding='same'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPool3D(pool_size=(2, 2, 2), padding='valid'))

    ##hidden layer 4 with Pooling
    #model.add(Conv3D(filters = 16, kernel_size=(1, 3, 3), input_shape=input_shape, activation='relu', padding='same'))
    #model.add(Dropout(dropout_rate))
    #model.add(MaxPool3D(pool_size=(2, 2, 2), padding='valid'))
    #model.add(BatchNormalization())

    model.add(Flatten())
    model.add(Dense(32, activation='sigmoid'))    
    model.add(Dense(32, activation='sigmoid'))
    model.add(Dense(unique_labs, activation='softmax'))

    return model

# %% [markdown]
# # Fitting the Neural Network Model
#
# Here we train the neural network model defined above. The training session will output loss, and accuracy at each epoch. We also plot the progression of the loss and accuracy with respect to training epochs after the training is completed.

# %%
# callbacks
checkpointer = ModelCheckpoint('keras_convnet_model.h5', verbose=1)
early_stopper = EarlyStopping(monitor='loss', patience=2, verbose=1)



cn_model = convnet_model(X_train.shape[1:], y_train)
cn_model.summary()

cn_model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=["accuracy"])
epochs = 90

start = time.time()

#classifier = cn_model.fit(X_train, y_train, epochs=80, batch_size=batch_size, callbacks=[early_stopper, checkpointer])
if not useSampleWeights:
    classifier = cn_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[checkpointer])
else:
    classifier = cn_model.fit(X_train, y_train, sample_weight = train_weight,
                              epochs=epochs, 
                              batch_size=batch_size, callbacks=[checkpointer])

end = time.time()
print('Process completed in', round(end-start, 2), ' seconds')

"""
Plot accuracy/loss versus epoch
"""

fig = pyl.figure(figsize=(10,3))

ax1 = pyl.subplot(121)
ax1.plot(classifier.history['accuracy'], color='darkslategray', linewidth=2)
ax1.set_title('Model Accuracy')
ax1.set_ylabel('Accuracy')
ax1.set_xlabel('Epoch')

ax2 = pyl.subplot(122)
ax2.plot(classifier.history['loss'], color='crimson', linewidth=2)
ax2.set_title('Model Loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')

pyl.show()
pyl.close()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 9, 21, 21, 32)     320
# _________________________________________________________________
# dropout (Dropout)            (None, 9, 21, 21, 32)     0
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 4, 10, 10, 32)     0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 4, 10, 10, 32)     9248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 10, 10, 32)     0
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 2, 5, 5, 32)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2, 5, 5, 32)       128
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 2, 5, 5, 32)       9248
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 5, 5, 32)       0
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 1, 2, 2, 32)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 24,194
# Trainable params: 24,130
# Non-trainable params: 64
# _________________________________________________________________
# Epoch 1/90
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.1768 - accuracy: 0.7228
# Epoch 00001: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1768 - accuracy: 0.7228
# Epoch 2/90
# 1681/1688 [============================>.] - ETA: 0s - loss: 0.1477 - accuracy: 0.7972
# Epoch 00002: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1476 - accuracy: 0.7974
# Epoch 3/90
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1438 - accuracy: 0.7969
# Epoch 00003: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1438 - accuracy: 0.7969
# Epoch 4/90
# 1670/1688 [============================>.] - ETA: 0s - loss: 0.1400 - accuracy: 0.8103
# Epoch 00004: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1402 - accuracy: 0.8104
# Epoch 5/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1376 - accuracy: 0.8198
# Epoch 00005: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1376 - accuracy: 0.8198
# Epoch 6/90
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.1368 - accuracy: 0.8213
# Epoch 00006: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1368 - accuracy: 0.8212
# Epoch 7/90
# 1678/1688 [============================>.] - ETA: 0s - loss: 0.1364 - accuracy: 0.8104
# Epoch 00007: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1364 - accuracy: 0.8104
# Epoch 8/90
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.1339 - accuracy: 0.8226
# Epoch 00008: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1338 - accuracy: 0.8228
# Epoch 9/90
# 1679/1688 [============================>.] - ETA: 0s - loss: 0.1339 - accuracy: 0.8205
# Epoch 00009: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1337 - accuracy: 0.8209
# Epoch 10/90
# 1683/1688 [============================>.] - ETA: 0s - loss: 0.1319 - accuracy: 0.8307
# Epoch 00010: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1319 - accuracy: 0.8305
# Epoch 11/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1312 - accuracy: 0.8286
# Epoch 00011: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1312 - accuracy: 0.8286
# Epoch 12/90
# 1674/1688 [============================>.] - ETA: 0s - loss: 0.1295 - accuracy: 0.8350
# Epoch 00012: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1294 - accuracy: 0.8352
# Epoch 13/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1294 - accuracy: 0.8287
# Epoch 00013: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1294 - accuracy: 0.8287
# Epoch 14/90
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.1282 - accuracy: 0.8348
# Epoch 00014: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1282 - accuracy: 0.8348
# Epoch 15/90
# 1683/1688 [============================>.] - ETA: 0s - loss: 0.1272 - accuracy: 0.8262
# Epoch 00015: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1272 - accuracy: 0.8261
# Epoch 16/90
# 1676/1688 [============================>.] - ETA: 0s - loss: 0.1265 - accuracy: 0.8343
# Epoch 00016: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1268 - accuracy: 0.8343
# Epoch 17/90
# 1681/1688 [============================>.] - ETA: 0s - loss: 0.1263 - accuracy: 0.8316
# Epoch 00017: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1264 - accuracy: 0.8317
# Epoch 18/90
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.8377
# Epoch 00018: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1250 - accuracy: 0.8377
# Epoch 19/90
# 1671/1688 [============================>.] - ETA: 0s - loss: 0.1246 - accuracy: 0.8306
# Epoch 00019: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1245 - accuracy: 0.8309
# Epoch 20/90
# 1676/1688 [============================>.] - ETA: 0s - loss: 0.1242 - accuracy: 0.8365
# Epoch 00020: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1242 - accuracy: 0.8366
# Epoch 21/90
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.1220 - accuracy: 0.8422
# Epoch 00021: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1219 - accuracy: 0.8422
# Epoch 22/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1222 - accuracy: 0.8299
# Epoch 00022: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1222 - accuracy: 0.8298
# Epoch 23/90
# 1683/1688 [============================>.] - ETA: 0s - loss: 0.1217 - accuracy: 0.8295
# Epoch 00023: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1218 - accuracy: 0.8293
# Epoch 24/90
# 1676/1688 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.8389
# Epoch 00024: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1208 - accuracy: 0.8386
# Epoch 25/90
# 1676/1688 [============================>.] - ETA: 0s - loss: 0.1193 - accuracy: 0.8392
# Epoch 00025: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1194 - accuracy: 0.8393
# Epoch 26/90
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.1196 - accuracy: 0.8422
# Epoch 00026: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1195 - accuracy: 0.8422
# Epoch 27/90
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.1194 - accuracy: 0.8374
# Epoch 00027: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1194 - accuracy: 0.8374
# Epoch 28/90
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.1186 - accuracy: 0.8335
# Epoch 00028: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1186 - accuracy: 0.8335
# Epoch 29/90
# 1675/1688 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.8457
# Epoch 00029: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1174 - accuracy: 0.8456
# Epoch 30/90
# 1673/1688 [============================>.] - ETA: 0s - loss: 0.1182 - accuracy: 0.8359
# Epoch 00030: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1181 - accuracy: 0.8362
# Epoch 31/90
# 1670/1688 [============================>.] - ETA: 0s - loss: 0.1171 - accuracy: 0.8451
# Epoch 00031: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1171 - accuracy: 0.8453
# Epoch 32/90
# 1680/1688 [============================>.] - ETA: 0s - loss: 0.1176 - accuracy: 0.8391
# Epoch 00032: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1178 - accuracy: 0.8388
# Epoch 33/90
# 1676/1688 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.8394
# Epoch 00033: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1172 - accuracy: 0.8396
# Epoch 34/90
# 1680/1688 [============================>.] - ETA: 0s - loss: 0.1163 - accuracy: 0.8536
# Epoch 00034: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1163 - accuracy: 0.8534
# Epoch 35/90
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.1166 - accuracy: 0.8432
# Epoch 00035: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1166 - accuracy: 0.8430
# Epoch 36/90
# 1683/1688 [============================>.] - ETA: 0s - loss: 0.1144 - accuracy: 0.8434
# Epoch 00036: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1144 - accuracy: 0.8433
# Epoch 37/90
# 1675/1688 [============================>.] - ETA: 0s - loss: 0.1141 - accuracy: 0.8383
# Epoch 00037: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1139 - accuracy: 0.8387
# Epoch 38/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1146 - accuracy: 0.8428
# Epoch 00038: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1146 - accuracy: 0.8428
# Epoch 39/90
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.8437
# Epoch 00039: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1148 - accuracy: 0.8436
# Epoch 40/90
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.8363
# Epoch 00040: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1145 - accuracy: 0.8363
# Epoch 41/90
# 1679/1688 [============================>.] - ETA: 0s - loss: 0.1141 - accuracy: 0.8341
# Epoch 00041: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1141 - accuracy: 0.8342
# Epoch 42/90
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.1124 - accuracy: 0.8471
# Epoch 00042: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1124 - accuracy: 0.8472
# Epoch 43/90
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.1130 - accuracy: 0.8450
# Epoch 00043: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1130 - accuracy: 0.8450
# Epoch 44/90
# 1683/1688 [============================>.] - ETA: 0s - loss: 0.1124 - accuracy: 0.8512
# Epoch 00044: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1125 - accuracy: 0.8512
# Epoch 45/90
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.1118 - accuracy: 0.8450
# Epoch 00045: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1118 - accuracy: 0.8450
# Epoch 46/90
# 1671/1688 [============================>.] - ETA: 0s - loss: 0.1112 - accuracy: 0.8445
# Epoch 00046: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1112 - accuracy: 0.8444
# Epoch 47/90
# 1682/1688 [============================>.] - ETA: 0s - loss: 0.1112 - accuracy: 0.8417
# Epoch 00047: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1112 - accuracy: 0.8418
# Epoch 48/90
# 1677/1688 [============================>.] - ETA: 0s - loss: 0.1109 - accuracy: 0.8495
# Epoch 00048: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1109 - accuracy: 0.8496
# Epoch 49/90
# 1682/1688 [============================>.] - ETA: 0s - loss: 0.1103 - accuracy: 0.8439
# Epoch 00049: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1103 - accuracy: 0.8438
# Epoch 50/90
# 1678/1688 [============================>.] - ETA: 0s - loss: 0.1109 - accuracy: 0.8382
# Epoch 00050: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1108 - accuracy: 0.8384
# Epoch 51/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1101 - accuracy: 0.8405
# Epoch 00051: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1101 - accuracy: 0.8406
# Epoch 52/90
# 1672/1688 [============================>.] - ETA: 0s - loss: 0.1089 - accuracy: 0.8449
# Epoch 00052: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1089 - accuracy: 0.8447
# Epoch 53/90
# 1678/1688 [============================>.] - ETA: 0s - loss: 0.1111 - accuracy: 0.8410
# Epoch 00053: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1112 - accuracy: 0.8408
# Epoch 54/90
# 1675/1688 [============================>.] - ETA: 0s - loss: 0.1092 - accuracy: 0.8442
# Epoch 00054: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1090 - accuracy: 0.8442
# Epoch 55/90
# 1675/1688 [============================>.] - ETA: 0s - loss: 0.1079 - accuracy: 0.8470
# Epoch 00055: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1077 - accuracy: 0.8474
# Epoch 56/90
# 1676/1688 [============================>.] - ETA: 0s - loss: 0.1088 - accuracy: 0.8420
# Epoch 00056: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1089 - accuracy: 0.8416
# Epoch 57/90
# 1676/1688 [============================>.] - ETA: 0s - loss: 0.1072 - accuracy: 0.8409
# Epoch 00057: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1077 - accuracy: 0.8410
# Epoch 58/90
# 1679/1688 [============================>.] - ETA: 0s - loss: 0.1074 - accuracy: 0.8485
# Epoch 00058: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1075 - accuracy: 0.8486
# Epoch 59/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.8484
# Epoch 00059: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1076 - accuracy: 0.8484
# Epoch 60/90
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.1059 - accuracy: 0.8435
# Epoch 00060: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1059 - accuracy: 0.8435
# Epoch 61/90
# 1682/1688 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.8474
# Epoch 00061: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1058 - accuracy: 0.8472
# Epoch 62/90
# 1681/1688 [============================>.] - ETA: 0s - loss: 0.1067 - accuracy: 0.8486
# Epoch 00062: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1067 - accuracy: 0.8487
# Epoch 63/90
# 1680/1688 [============================>.] - ETA: 0s - loss: 0.1061 - accuracy: 0.8417
# Epoch 00063: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1059 - accuracy: 0.8419
# Epoch 64/90
# 1672/1688 [============================>.] - ETA: 0s - loss: 0.1064 - accuracy: 0.8422
# Epoch 00064: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1064 - accuracy: 0.8420
# Epoch 65/90
# 1673/1688 [============================>.] - ETA: 0s - loss: 0.1051 - accuracy: 0.8468
# Epoch 00065: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1049 - accuracy: 0.8472
# Epoch 66/90
# 1683/1688 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.8480
# Epoch 00066: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1079 - accuracy: 0.8478
# Epoch 67/90
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.8511
# Epoch 00067: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1057 - accuracy: 0.8511
# Epoch 68/90
# 1674/1688 [============================>.] - ETA: 0s - loss: 0.1047 - accuracy: 0.8412
# Epoch 00068: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1048 - accuracy: 0.8410
# Epoch 69/90
# 1677/1688 [============================>.] - ETA: 0s - loss: 0.1043 - accuracy: 0.8458
# Epoch 00069: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1045 - accuracy: 0.8457
# Epoch 70/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1048 - accuracy: 0.8497
# Epoch 00070: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1048 - accuracy: 0.8497
# Epoch 71/90
# 1673/1688 [============================>.] - ETA: 0s - loss: 0.1022 - accuracy: 0.8565
# Epoch 00071: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1023 - accuracy: 0.8569
# Epoch 72/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1045 - accuracy: 0.8434
# Epoch 00072: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1045 - accuracy: 0.8434
# Epoch 73/90
# 1672/1688 [============================>.] - ETA: 0s - loss: 0.1041 - accuracy: 0.8518
# Epoch 00073: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1043 - accuracy: 0.8517
# Epoch 74/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1050 - accuracy: 0.8528
# Epoch 00074: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1049 - accuracy: 0.8528
# Epoch 75/90
# 1680/1688 [============================>.] - ETA: 0s - loss: 0.1026 - accuracy: 0.8530
# Epoch 00075: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1025 - accuracy: 0.8532
# Epoch 76/90
# 1676/1688 [============================>.] - ETA: 0s - loss: 0.1026 - accuracy: 0.8512
# Epoch 00076: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1025 - accuracy: 0.8514
# Epoch 77/90
# 1682/1688 [============================>.] - ETA: 0s - loss: 0.1027 - accuracy: 0.8519
# Epoch 00077: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1029 - accuracy: 0.8516
# Epoch 78/90
# 1679/1688 [============================>.] - ETA: 0s - loss: 0.1041 - accuracy: 0.8535
# Epoch 00078: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1041 - accuracy: 0.8534
# Epoch 79/90
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1029 - accuracy: 0.8511
# Epoch 00079: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1029 - accuracy: 0.8510
# Epoch 80/90
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.8524
# Epoch 00080: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1028 - accuracy: 0.8524
# Epoch 81/90
# 1682/1688 [============================>.] - ETA: 0s - loss: 0.1020 - accuracy: 0.8489
# Epoch 00081: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1019 - accuracy: 0.8491
# Epoch 82/90
# 1672/1688 [============================>.] - ETA: 0s - loss: 0.1014 - accuracy: 0.8506
# Epoch 00082: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1013 - accuracy: 0.8508
# Epoch 83/90
# 1673/1688 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.8549
# Epoch 00083: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1012 - accuracy: 0.8551
# Epoch 84/90
# 1671/1688 [============================>.] - ETA: 0s - loss: 0.1011 - accuracy: 0.8571
# Epoch 00084: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1011 - accuracy: 0.8570
# Epoch 85/90
# 1673/1688 [============================>.] - ETA: 0s - loss: 0.1015 - accuracy: 0.8523
# Epoch 00085: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1017 - accuracy: 0.8524
# Epoch 86/90
# 1681/1688 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.8514
# Epoch 00086: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1009 - accuracy: 0.8515
# Epoch 87/90
# 1678/1688 [============================>.] - ETA: 0s - loss: 0.1008 - accuracy: 0.8478
# Epoch 00087: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1008 - accuracy: 0.8476
# Epoch 88/90
# 1674/1688 [============================>.] - ETA: 0s - loss: 0.1003 - accuracy: 0.8556
# Epoch 00088: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1003 - accuracy: 0.8554
# Epoch 89/90
# 1674/1688 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.8489
# Epoch 00089: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1010 - accuracy: 0.8488
# Epoch 90/90
# 1675/1688 [============================>.] - ETA: 0s - loss: 0.0994 - accuracy: 0.8594
# Epoch 00090: saving model to keras_convnet_model.h5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0995 - accuracy: 0.8588
# Process completed in 453.69  seconds

# %% [markdown]
# # Save the Model

# %%
saveModel = False
if saveModel:
    cn_model.save('IMPROVETESTING_save')
    
    with open('IMPROVETESTING_save/median.properties', 'w+') as outhan:
        print(mean, std, file=outhan)
#    
#if save_model_iteration:
#    i = int(np.random.rand(1)*1000)
#    output_fn = f'TEST_model_saves/prod_save_{i}'
#    cn_model.save(output_fn)
#    print(f'\n   saved to {output_fn}\n')
#    with open(f'{output_fn}/median.properties','w+') as han:
#        print(f'{med, std, mean}', file=han)

# %% [markdown]
# # Validation
#
# Finally, we use the model trained above to make predictions on the test/validation sample. We then compare these predicted labels with the original ones, and derive a prediction accuracy.

# %%
preds_test = cn_model.predict(X_test, verbose=1)

preds_train = cn_model.predict(X_train, verbose=1)
# Out:
# 45/45 [==============================] - 0s 1ms/step
# 844/844 [==============================] - 1s 1ms/step

# %%
pyl.figure(figsize=(10,10))
pyl.hist(preds_train[:, 1], bins=200, density=True,alpha=0.5, label='Train', log=True)
pyl.hist(preds_test[:, 1], bins=200, density=True,alpha=0.5,label='Test', log=True)
pyl.legend()
pyl.show()

# %%
# measure the distribution of p values as a function of magnitude
eff_fig = pyl.figure('Efficiency Estimate', figsize=(12, 8))
eff_sp = eff_fig.add_subplot(111)
eff_sp.set_xlabel('r')
eff_sp.set_ylabel('e(r)')
                  
figure = pyl.figure('P-value histogram', figsize=(12, 12))
sp = figure.add_subplot(111)

good_p_value = 0.99
m_step = 0.25

print(len(np.where(preds_test>good_p_value)[0]))

bins = np.linspace(0.0,1.0,10000)
n_false = bins*0.0
n_found = 0.0
K = np.sum(np.less(bins,good_p_value))
for m in np.arange(19.,28.,m_step):
    # plot the P-value cumulative distributions
    w = np.where( ((source_details[test_index, 5]-m)>=0) & ((source_details[test_index, 5]-m)<=m_step) )
    p_values = preds_test[w[0],1]
    
    n = bins*0.0
    k = ((p_values-bins[0])/(bins[1]-bins[0])).astype(np.int)
    for i in k:
        n[i:]+=1.0
    n_found+=n[-1]-n[K]
    n/=n[-1]
    
    
    # plot the efficiency curve estimate
    
    sp.plot(bins,n,label=f'{m}<=r<={m+m_step}')
    eff_sp.scatter(m+m_step/2.,1.0-n[K])
    if len(p_values)>0:
        print(m, np.min(p_values), np.max(p_values), 1.0-n[K] )

    
    # now sum up the false positives
    w = np.where( (source_details[test_index, 5])==0) 
    p_values_false = preds_test[w[0],1]
    
    k = ((p_values_false-bins[0])/(bins[1]-bins[0])).astype(np.int)
    for i in k:
        n_false[:i]+=1.0

print()
print(f'Number of false-marked candidates with P>{good_p_value}:',np.sum(n_false[K:]))
print(f'Number of sources marked as real with P>{good_p_value}:',n_found)

n_false/=n_false[0]
pyl.plot(bins, n_false,'k:', lw=4)

eff_sp.grid()
    
pyl.plot([0, 1], [0.1, 0.1], 'k--')
pyl.plot([0, 1], [0.3, 0.3], 'k--')
pyl.plot([0, 1], [0.5, 0.5], 'k--')
pyl.plot([0, 1], [0.7, 0.7], 'k--')
pyl.plot([good_p_value, good_p_value], [0, 1], 'k:')
sp.legend()
sp.set_yscale('log')
sp.set_xlim(0.99,1.0)
pyl.xlabel('P(is real)')
pyl.ylabel('N(p<P)')
pyl.show()
# Out:
# 509
# 20.5 0.99915826 0.99918634 1.0
# 20.75 0.99865216 0.999403 1.0
# 21.0 0.99919325 0.99937135 1.0
# 21.25 0.999129 0.9993961 1.0
# 21.5 0.99842864 0.99940073 1.0
# 21.75 0.9882308 0.99922407 0.875
# 22.0 0.99772435 0.9994041 1.0
# 22.25 0.9971937 0.9991881 1.0
# 22.5 0.99866307 0.9991573 1.0
# 22.75 0.9629915 0.9989472 0.6
# 23.0 0.8143275 0.99916184 0.7692307692307692
# 23.25 0.69185525 0.9989736 0.5
# 23.5 0.66351 0.9989471 0.2666666666666667
# 23.75 0.660409 0.99894756 0.8
# 24.0 0.44081408 0.9989471 0.33333333333333337
# 24.25 0.33842352 0.9989471 0.5
# 24.5 0.116933815 0.9989471 0.2857142857142857
# 24.75 0.44120547 0.9989471 0.19999999999999996
# 25.0 0.18540673 0.9989492 0.625
# 25.25 0.30980644 0.9989471 0.47058823529411764
# 25.5 0.25695688 0.9989373 0.48
# 25.75 0.23068881 0.9990969 0.44999999999999996
# 26.0 0.25335008 0.998858 0.33333333333333337
# 26.25 0.0024906336 0.99756277 0.13043478260869568
# 26.5 0.08747172 0.9946727 0.1428571428571429
# 26.75 0.00758644 0.8673929 0.0
# 27.0 0.062459994 0.9525631 0.0
#
# Number of false-marked candidates with P>0.99: 11844.0
# Number of sources marked as real with P>0.99: 134.0
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /home/fraserw/anaconda3/envs/keras/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide

# %%
preds_test_t = (preds_test > 0.5).astype(np.uint8)




X_test_plot = np.squeeze(X_test, axis=4)
X_train_plot = np.squeeze(X_train, axis=4)

print('Fraction of correct predictions: ', round(accuracy_score(y_test, preds_test_t), 3))

cut = make_display_image(X_test_plot[-1], 3)
pyl.imshow(cut, origin='lower')
pyl.show()


"""
for i in range(len(preds_test)):
    if y_test[i][1] == 1 and preds_test[i][1]>0.05:
        cut = make_display_image(X_test_plot[i])
        pyl.imshow(cut, origin='lower')
        pyl.title('Orig:' + str(y_test[i]) + '| Pred:' + str(preds_test[i])+' '+str(source_details[test_index[i]]))
        pyl.show()
print('next')
"""

"""
n=0
for i in range(len(preds_train)):
    if y_train[i][1] == 1 and preds_train[i][1]>0.5 and source_details[train_index[i]][2]>=25:
        cut = make_display_image(X_train_plot[i])
        pyl.imshow(cut, origin='lower')
        pyl.title('Orig:' + str(y_train[i]) + '| Pred:' + str(preds_train[i])+' '+str(source_details[train_index[i]]))
        pyl.show()
        n+=1

print(n,len(preds_test))
"""

"""
print('next next')
for i in range(len(preds_train)):
    if y_train[i][1] == 0 and preds_train[i][1]>0.95:
        cut = make_display_image(X_train_plot[i])
        pyl.imshow(cut, origin='lower')
        pyl.title('Orig:' + str(y_train[i]) + '| Pred:' + str(preds_train[i])+' '+str(source_details[train_index[i]]))
        pyl.show()
for i in range(len(preds_test)):
    if y_test[i][1] == 0 and preds_test[i][1]>0.95:
        cut = make_display_image(X_test_plot[i])
        pyl.imshow(cut, origin='lower')
        pyl.title('Orig:' + str(y_test[i]) + '| Pred:' + str(preds_test[i])+' '+str(source_details[test_index[i]]))
        pyl.show()

"""
# Out:
# Fraction of correct predictions:  0.764
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-913019d57182> in <module>()
#       9 print('Fraction of correct predictions: ', round(accuracy_score(y_test, preds_test_t), 3))
#      10
# ---> 11 cut = make_display_image(X_test_plot[-1], 3)
#      12 pyl.imshow(cut, origin='lower')
#      13 pyl.show()
#
# NameError: name 'make_display_image' is not defined
